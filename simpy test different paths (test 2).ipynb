# %%
import simpy
from numpy.random import choice

# %%
n=5 #Prime router number
N=3 #regular router number
m=3 #shortest path number

# %%
class Packet(object):
    """ A very simple class that represents a packet.
        This packet will run through a queue at a switch output port.
        We use a float to represent the size of the packet in bytes so that
        we can compare to ideal M/M/1 queues.

        Parameters
        ----------
        time : float
            the time the packet arrives at the output queue.
        size : float
            the size of the packet in bytes
        id : int
            an identifier for the packet
        src, dst : int
            identifiers for source and destination

    """
    def __init__(self, packet_id, path, cur_path_ind, time, size, src, dst):
        
        self.packet_id=packet_id
        self.path=path
        self.cur_path_ind=cur_path_ind
        
        
        self.time = time
        self.size = size
        self.src = src
        self.dst = dst


    def __repr__(self):
        return "id: {}, src: {}, time: {}, size: {}".\
            format(self.packet_id, self.src, self.time, self.size)

# %% [markdown]
# '''path, cur_path_ind, '''

# %%
class PacketGenerator(object):
    """ Generates packets with given inter-arrival time distribution.
        Set the "out" member variable to the entity to receive the packet.

        Parameters
        ----------
        env : simpy.Environment
            the simulation environment
        adist : function
            a no parameter function that returns the successive inter-arrival times of the packets
        sdist : function
            a no parameter function that returns the successive sizes of the packets
        initial_delay : number
            Starts generation after an initial delay. Default = 0
        finish : number
            Stops generation at the finish time. Default is infinite


    """
    def __init__(self, env, gen_prob, generator_id,  adist, sdist, initial_delay=0, finish=float("inf")):
        
        self.gen_prob=gen_prob
        self.generator_id = generator_id
        self.env = env
        self.adist = adist
        self.sdist = sdist
        self.initial_delay = initial_delay
        self.finish = finish
        self.out = None
        self.packets_sent = 0
        self.action = env.process(self.run())  # starts the run() method as a SimPy process


    def run(self):
        """The generator function used in simulations.
        """
        
        yield self.env.timeout(self.initial_delay)
        while self.env.now < self.finish:
            # wait for next transmission
            yield self.env.timeout(self.adist())
            
            destination = choice(range(1,N+1), p=self.gen_prob)
            #print('destination',destination)
            #print('id',self.generator_id)
            opt_path=path[self.generator_id][destination]
            
           #print('opt_path',opt_path)
            
            self.packets_sent += 1
            
            
            pkt = Packet(packet_id=self.packets_sent, 
                         path=opt_path, 
                         cur_path_ind=0, 
                         time=self.env.now, 
                         size=self.sdist(), 
                         src=self.generator_id, 
                         dst=destination)
            
            #if next_node==destination:
            #    sink[destination].put(p)
            #else:
            #    switch[destination].put(p)
            
            self.out.put(pkt)

# %%
class PacketSink(object):
    """ Receives packets and collects delay information into the
        waits list. You can then use this list to look at delay statistics.

        Parameters
        ----------
        env : simpy.Environment
            the simulation environment
        debug : boolean
            if true then the contents of each packet will be printed as it is received.
        rec_arrivals : boolean
            if true then arrivals will be recorded
        absolute_arrivals : boolean
            if true absolute arrival times will be recorded, otherwise the time between consecutive arrivals
            is recorded.
        rec_waits : boolean
            if true waiting time experienced by each packet is recorded
        selector: a function that takes a packet and returns a boolean
            used for selective statistics. Default none.

    """
    def __init__(self, env, rec_arrivals=False, absolute_arrivals=False, rec_waits=True, debug=False, selector=None):
        self.store = simpy.Store(env)
        self.env = env
        self.rec_waits = rec_waits
        self.rec_arrivals = rec_arrivals
        self.absolute_arrivals = absolute_arrivals
        self.waits = []
        self.arrivals = []
        self.debug = debug
        self.packets_rec = 0
        self.bytes_rec = 0
        self.selector = selector
        self.last_arrival = 0.0

    def put(self, pkt):
        #print('packet_id',pkt.id)
        print('sink haha', pkt.packet_id, pkt.src)
        
        if not self.selector or self.selector(pkt):
            now = self.env.now
            if self.rec_waits:
                self.waits.append(self.env.now - pkt.time)
            if self.rec_arrivals:
                if self.absolute_arrivals:
                    self.arrivals.append(now)
                else:
                    self.arrivals.append(now - self.last_arrival)
                self.last_arrival = now
            self.packets_rec += 1
            self.bytes_rec += pkt.size
            if self.debug:
                print(pkt)

# %%
def put_in_queue(i,pkt):
    
    
    switch[i].packets_rec += 1
    tmp_byte_count = switch[i].byte_size + pkt.size

    #if switch[i].qlimit is None:
    #    switch[i].byte_size = tmp_byte_count
    #    return switch[i].store.put(pkt)
    if switch[i].limit_bytes and tmp_byte_count >= switch[i].qlimit:
        switch[i].packets_drop += 1
        return
    #elif not switch[i].limit_bytes and len(switch[i].store.items) >= switch[i].qlimit-1:
    #    switch[i].packets_drop += 1
    else:
        switch[i].byte_size = tmp_byte_count
        switch[i].store.put(pkt)
        #print('router', i, 'store', self.store.items)
        return

# %%
class SwitchPort(object):
    """ Models a switch output port with a given rate and buffer size limit in bytes.
        Set the "out" member variable to the entity to receive the packet.

        Parameters
        ----------
        env : simpy.Environment
            the simulation environment
        rate : float
            the bit rate of the port
        qlimit : integer (or None)
            a buffer size limit in bytes or packets for the queue (including items
            in service).
        limit_bytes : If true, the queue limit will be based on bytes if false the
            queue limit will be based on packets.

    """
    def __init__(self, env, router_id, rate, qlimit=None, limit_bytes=True, debug=False):
        self.router_id=router_id
        self.store = simpy.Store(env)
        self.rate = rate
        self.env = env
        self.out = None
        self.packets_rec = 0
        self.packets_drop = 0
        self.qlimit = qlimit
        self.limit_bytes = limit_bytes
        self.byte_size = 0  # Current size of the queue in bytes
        self.debug = debug
        self.busy = 0  # Used to track if a packet is currently being sent
        self.action = env.process(self.run())  # starts the run() method as a SimPy process

    def run(self):

        while True:
            msg = (yield self.store.get())
            self.busy = 1
            self.byte_size -= msg.size
            yield self.env.timeout(msg.size*8.0/self.rate)
            
            #print('msg', msg.packet_id, msg.src, 'router', self.router_id)
            #self.out=switch[1]
            #self.out.put(msg)
            #self.busy = 0
            #if self.debug:
            #    print(msg)
 
            path=msg.path
            cur_path_ind=msg.cur_path_ind
            destination=msg.dst
                
            #print('path',path)
            #print('cur_path_ind',cur_path_ind)
            #print('destination',destination)
            #print('path[cur_path_ind]',path[cur_path_ind])
            
            #self.packet_id=packet_id
            #self.path=path
            #self.cur_path_ind=cur_path_ind
            #print('msg packet_id src ',msg.packet_id, msg.src)
                
            if path[cur_path_ind]==destination:
                #print('send to sink' + str(destination))
                sink.put(msg)
            else:
                next_node=path[cur_path_ind+1]
                #print('send to switch' + str(next_node))
                msg.cur_path_ind=cur_path_ind+1
                #print('msg.cur_path_ind_after',msg.cur_path_ind)
                
                #put_in_queue(next_node,msg)
                
                
                switch[next_node].store.put(msg)   
                
                #print('msg', msg.packet_id, msg.src)
                #switch[next_node].put(msg)
                
                #switch_for_switches.put((msg, next_node))
                
            self.busy = 0
            #if self.debug:
            #    print(msg)
                
     

    def put(self, pkt):
        #put_in_queue(i,pkt)
        self.packets_rec += 1
        tmp_byte_count = self.byte_size + pkt.size

        #if switch[i].qlimit is None:
        #    switch[i].byte_size = tmp_byte_count
        #    return switch[i].store.put(pkt)
        if self.limit_bytes and tmp_byte_count >= self.qlimit:
            self.packets_drop += 1
            return
        #elif not switch[i].limit_bytes and len(switch[i].store.items) >= switch[i].qlimit-1:
        #    switch[i].packets_drop += 1
        else:
            self.byte_size = tmp_byte_count
            self.store.put(pkt)
            #prifnt('router', i, 'store', self.store.items)
            return

# %%
from random import expovariate
import simpy

def constArrival():  # Constant arrival distribution for generator 1
    return 1.5

def constArrival2():
    return 2.0

def distSize():
    return expovariate(0.01)

# %%
def constArrival():
    return 1.5    # time interval

def constSize():
    return 100.0  # bytes

# %%
path=[0]*4
prob=[0]*4
for i in range(4):
    path[i]=[0]*4


path[1][2]=[1,3,2]
path[2][3]=[2,1,3]
path[3][1]=[3,2,1]
path[2][1]=[2,3,1]
path[3][2]=[3,1,2]
path[1][3]=[1,2,3]

gen_prob=[0]*4
gen_prob[1]=[0,0.5,0.5]
gen_prob[2]=[0.2,0,0.8]
gen_prob[3]=[0.7,0.3,0]

# %%
path
# Out:
# [[0, 0, 0, 0],
#  [0, 0, [1, 3, 2], [1, 2, 3]],
#  [0, [2, 3, 1], 0, [2, 1, 3]],
#  [0, [3, 2, 1], [3, 1, 2], 0]]

# %%
import numpy as np

generators=[0]*4
#switch=np.array([0]*4)
switch=[0]*4

env = simpy.Environment()  # Create the SimPy environment

sink=PacketSink(env, debug=True)



#switchx=SwitchPort(env, 100, rate=200.0, qlimit=300, debug=True)
#switch_for_switches=SwitchForSwitches(env)



for i in range(1,4):
    generators[i]=PacketGenerator(env, gen_prob[i], i, constArrival, constSize)
    switch[i]=SwitchPort(env=env, router_id=i, rate=1000.0, qlimit=30000, debug=True)
    #switch[i].out=
    generators[i].out = switch[i]
    #switch[i].out=switchx
    #sink[i]=PacketSink(env, debug=True)
    

#switchx.out=sink
    
env.run(until=2000)
print("sink waits: {}".format(sink.waits))

for i in range(1,4):
    print("{} received: {}, dropped {}, sent {}".format(i, sink.packets_rec,
         switch[i].packets_drop, generators[i].packets_sent))
# Out:
# sink haha 1 1
# id: 1, src: 1, time: 1.5, size: 100.0
# sink haha 1 3
# id: 1, src: 3, time: 1.5, size: 100.0
# sink haha 1 2
# id: 1, src: 2, time: 1.5, size: 100.0
# sink haha 2 3
# id: 2, src: 3, time: 3.0, size: 100.0
# sink haha 2 1
# id: 2, src: 1, time: 3.0, size: 100.0
# sink haha 2 2
# id: 2, src: 2, time: 3.0, size: 100.0
# sink haha 3 1
# id: 3, src: 1, time: 4.5, size: 100.0
# sink haha 3 2
# id: 3, src: 2, time: 4.5, size: 100.0
# sink haha 3 3
# id: 3, src: 3, time: 4.5, size: 100.0
# sink haha 4 3
# id: 4, src: 3, time: 6.0, size: 100.0
# sink haha 4 2
# id: 4, src: 2, time: 6.0, size: 100.0
# sink haha 5 1
# id: 5, src: 1, time: 7.5, size: 100.0
# sink haha 4 1
# id: 4, src: 1, time: 6.0, size: 100.0
# sink haha 5 3
# id: 5, src: 3, time: 7.5, size: 100.0
# sink haha 5 2
# id: 5, src: 2, time: 7.5, size: 100.0
# sink haha 6 2
# id: 6, src: 2, time: 9.0, size: 100.0
# sink haha 6 1
# id: 6, src: 1, time: 9.0, size: 100.0
# sink haha 6 3
# id: 6, src: 3, time: 9.0, size: 100.0
# sink haha 7 2
# id: 7, src: 2, time: 10.5, size: 100.0
# sink haha 7 3
# id: 7, src: 3, time: 10.5, size: 100.0
# sink haha 8 1
# id: 8, src: 1, time: 12.0, size: 100.0
# sink haha 7 1
# id: 7, src: 1, time: 10.5, size: 100.0
# sink haha 8 2
# id: 8, src: 2, time: 12.0, size: 100.0
# sink haha 8 3
# id: 8, src: 3, time: 12.0, size: 100.0
# sink haha 9 1
# id: 9, src: 1, time: 13.5, size: 100.0
# sink haha 9 2
# id: 9, src: 2, time: 13.5, size: 100.0
# sink haha 9 3
# id: 9, src: 3, time: 13.5, size: 100.0
# sink haha 10 1
# id: 10, src: 1, time: 15.0, size: 100.0
# sink haha 10 2
# id: 10, src: 2, time: 15.0, size: 100.0
# sink haha 10 3
# id: 10, src: 3, time: 15.0, size: 100.0
# sink haha 12 1
# id: 12, src: 1, time: 18.0, size: 100.0
# sink haha 11 2
# id: 11, src: 2, time: 16.5, size: 100.0
# sink haha 12 3
# id: 12, src: 3, time: 18.0, size: 100.0
# sink haha 11 1
# id: 11, src: 1, time: 16.5, size: 100.0
# sink haha 11 3
# id: 11, src: 3, time: 16.5, size: 100.0
# sink haha 13 3
# id: 13, src: 3, time: 19.5, size: 100.0
# sink haha 12 2
# id: 12, src: 2, time: 18.0, size: 100.0
# sink haha 13 1
# id: 13, src: 1, time: 19.5, size: 100.0
# sink haha 14 3
# id: 14, src: 3, time: 21.0, size: 100.0
# sink haha 13 2
# id: 13, src: 2, time: 19.5, size: 100.0
# sink haha 14 1
# id: 14, src: 1, time: 21.0, size: 100.0
# sink haha 15 3
# id: 15, src: 3, time: 22.5, size: 100.0
# sink haha 14 2
# id: 14, src: 2, time: 21.0, size: 100.0
# sink haha 16 3
# id: 16, src: 3, time: 24.0, size: 100.0
# sink haha 15 2
# id: 15, src: 2, time: 22.5, size: 100.0
# sink haha 16 2
# id: 16, src: 2, time: 24.0, size: 100.0
# sink haha 15 1
# id: 15, src: 1, time: 22.5, size: 100.0
# sink haha 16 1
# id: 16, src: 1, time: 24.0, size: 100.0
# sink haha 17 3
# id: 17, src: 3, time: 25.5, size: 100.0
# sink haha 17 2
# id: 17, src: 2, time: 25.5, size: 100.0
# sink haha 17 1
# id: 17, src: 1, time: 25.5, size: 100.0
# sink haha 18 2
# id: 18, src: 2, time: 27.0, size: 100.0
# sink haha 19 2
# id: 19, src: 2, time: 28.5, size: 100.0
# sink haha 18 3
# id: 18, src: 3, time: 27.0, size: 100.0
# sink haha 18 1
# id: 18, src: 1, time: 27.0, size: 100.0
# sink haha 19 1
# id: 19, src: 1, time: 28.5, size: 100.0
# sink haha 19 3
# id: 19, src: 3, time: 28.5, size: 100.0
# sink haha 20 1
# id: 20, src: 1, time: 30.0, size: 100.0
# sink haha 20 2
# id: 20, src: 2, time: 30.0, size: 100.0
# sink haha 21 1
# id: 21, src: 1, time: 31.5, size: 100.0
# sink haha 21 2
# id: 21, src: 2, time: 31.5, size: 100.0
# sink haha 20 3
# id: 20, src: 3, time: 30.0, size: 100.0
# sink haha 22 2
# id: 22, src: 2, time: 33.0, size: 100.0
# sink haha 21 3
# id: 21, src: 3, time: 31.5, size: 100.0
# sink haha 23 2
# id: 23, src: 2, time: 34.5, size: 100.0
# sink haha 22 1
# id: 22, src: 1, time: 33.0, size: 100.0
# sink haha 23 3
# id: 23, src: 3, time: 34.5, size: 100.0
# sink haha 24 2
# id: 24, src: 2, time: 36.0, size: 100.0
# sink haha 22 3
# id: 22, src: 3, time: 33.0, size: 100.0
# sink haha 23 1
# id: 23, src: 1, time: 34.5, size: 100.0
# sink haha 24 3
# id: 24, src: 3, time: 36.0, size: 100.0
# sink haha 25 2
# id: 25, src: 2, time: 37.5, size: 100.0
# sink haha 24 1
# id: 24, src: 1, time: 36.0, size: 100.0
# sink haha 25 1
# id: 25, src: 1, time: 37.5, size: 100.0
# sink haha 26 2
# id: 26, src: 2, time: 39.0, size: 100.0
# sink haha 25 3
# id: 25, src: 3, time: 37.5, size: 100.0
# sink haha 26 3
# id: 26, src: 3, time: 39.0, size: 100.0
# sink haha 27 2
# id: 27, src: 2, time: 40.5, size: 100.0
# sink haha 27 1
# id: 27, src: 1, time: 40.5, size: 100.0
# sink haha 27 3
# id: 27, src: 3, time: 40.5, size: 100.0
# sink haha 28 2
# id: 28, src: 2, time: 42.0, size: 100.0
# sink haha 26 1
# id: 26, src: 1, time: 39.0, size: 100.0
# sink haha 28 3
# id: 28, src: 3, time: 42.0, size: 100.0
# sink haha 28 1
# id: 28, src: 1, time: 42.0, size: 100.0
# sink haha 30 2
# id: 30, src: 2, time: 45.0, size: 100.0
# sink haha 29 2
# id: 29, src: 2, time: 43.5, size: 100.0
# sink haha 29 3
# id: 29, src: 3, time: 43.5, size: 100.0
# sink haha 29 1
# id: 29, src: 1, time: 43.5, size: 100.0
# sink haha 31 2
# id: 31, src: 2, time: 46.5, size: 100.0
# sink haha 30 3
# id: 30, src: 3, time: 45.0, size: 100.0
# sink haha 30 1
# id: 30, src: 1, time: 45.0, size: 100.0
# sink haha 31 3
# id: 31, src: 3, time: 46.5, size: 100.0
# sink haha 31 1
# id: 31, src: 1, time: 46.5, size: 100.0
# sink haha 32 1
# id: 32, src: 1, time: 48.0, size: 100.0
# sink haha 32 3
# id: 32, src: 3, time: 48.0, size: 100.0
# sink haha 32 2
# id: 32, src: 2, time: 48.0, size: 100.0
# sink haha 33 3
# id: 33, src: 3, time: 49.5, size: 100.0
# sink haha 33 2
# id: 33, src: 2, time: 49.5, size: 100.0
# sink haha 34 2
# id: 34, src: 2, time: 51.0, size: 100.0
# sink haha 33 1
# id: 33, src: 1, time: 49.5, size: 100.0
# sink haha 36 2
# id: 36, src: 2, time: 54.0, size: 100.0
# sink haha 34 3
# id: 34, src: 3, time: 51.0, size: 100.0
# sink haha 35 3
# id: 35, src: 3, time: 52.5, size: 100.0
# sink haha 35 2
# id: 35, src: 2, time: 52.5, size: 100.0
# sink haha 34 1
# id: 34, src: 1, time: 51.0, size: 100.0
# sink haha 35 1
# id: 35, src: 1, time: 52.5, size: 100.0
# sink haha 37 2
# id: 37, src: 2, time: 55.5, size: 100.0
# sink haha 36 1
# id: 36, src: 1, time: 54.0, size: 100.0
# sink haha 37 3
# id: 37, src: 3, time: 55.5, size: 100.0
# sink haha 37 1
# id: 37, src: 1, time: 55.5, size: 100.0
# sink haha 38 2
# id: 38, src: 2, time: 57.0, size: 100.0
# sink haha 36 3
# id: 36, src: 3, time: 54.0, size: 100.0
# sink haha 38 3
# id: 38, src: 3, time: 57.0, size: 100.0
# sink haha 39 2
# id: 39, src: 2, time: 58.5, size: 100.0
# sink haha 39 3
# id: 39, src: 3, time: 58.5, size: 100.0
# sink haha 40 2
# id: 40, src: 2, time: 60.0, size: 100.0
# sink haha 40 3
# id: 40, src: 3, time: 60.0, size: 100.0
# sink haha 39 1
# id: 39, src: 1, time: 58.5, size: 100.0
# sink haha 38 1
# id: 38, src: 1, time: 57.0, size: 100.0
# sink haha 41 2
# id: 41, src: 2, time: 61.5, size: 100.0
# sink haha 41 1
# id: 41, src: 1, time: 61.5, size: 100.0
# sink haha 42 2
# id: 42, src: 2, time: 63.0, size: 100.0
# sink haha 41 3
# id: 41, src: 3, time: 61.5, size: 100.0
# sink haha 40 1
# id: 40, src: 1, time: 60.0, size: 100.0
# sink haha 43 2
# id: 43, src: 2, time: 64.5, size: 100.0
# sink haha 42 3
# id: 42, src: 3, time: 63.0, size: 100.0
# sink haha 42 1
# id: 42, src: 1, time: 63.0, size: 100.0
# sink haha 44 2
# id: 44, src: 2, time: 66.0, size: 100.0
# sink haha 43 3
# id: 43, src: 3, time: 64.5, size: 100.0
# sink haha 43 1
# id: 43, src: 1, time: 64.5, size: 100.0
# sink haha 44 3
# id: 44, src: 3, time: 66.0, size: 100.0
# sink haha 46 2
# id: 46, src: 2, time: 69.0, size: 100.0
# sink haha 45 3
# id: 45, src: 3, time: 67.5, size: 100.0
# sink haha 45 2
# id: 45, src: 2, time: 67.5, size: 100.0
# sink haha 47 2
# id: 47, src: 2, time: 70.5, size: 100.0
# sink haha 44 1
# id: 44, src: 1, time: 66.0, size: 100.0
# sink haha 46 3
# id: 46, src: 3, time: 69.0, size: 100.0
# sink haha 48 2
# id: 48, src: 2, time: 72.0, size: 100.0
# sink haha 45 1
# id: 45, src: 1, time: 67.5, size: 100.0
# sink haha 47 3
# id: 47, src: 3, time: 70.5, size: 100.0
# sink haha 49 2
# id: 49, src: 2, time: 73.5, size: 100.0
# sink haha 46 1
# id: 46, src: 1, time: 69.0, size: 100.0
# sink haha 48 3
# id: 48, src: 3, time: 72.0, size: 100.0
# sink haha 47 1
# id: 47, src: 1, time: 70.5, size: 100.0
# sink haha 50 2
# id: 50, src: 2, time: 75.0, size: 100.0
# sink haha 48 1
# id: 48, src: 1, time: 72.0, size: 100.0
# sink haha 49 3
# id: 49, src: 3, time: 73.5, size: 100.0
# sink haha 49 1
# id: 49, src: 1, time: 73.5, size: 100.0
# sink haha 51 2
# id: 51, src: 2, time: 76.5, size: 100.0
# sink haha 51 3
# id: 51, src: 3, time: 76.5, size: 100.0
# sink haha 50 1
# id: 50, src: 1, time: 75.0, size: 100.0
# sink haha 52 2
# id: 52, src: 2, time: 78.0, size: 100.0
# sink haha 50 3
# id: 50, src: 3, time: 75.0, size: 100.0
# sink haha 52 1
# id: 52, src: 1, time: 78.0, size: 100.0
# sink haha 51 1
# id: 51, src: 1, time: 76.5, size: 100.0
# sink haha 53 1
# id: 53, src: 1, time: 79.5, size: 100.0
# sink haha 52 3
# id: 52, src: 3, time: 78.0, size: 100.0
# sink haha 53 2
# id: 53, src: 2, time: 79.5, size: 100.0
# sink haha 53 3
# id: 53, src: 3, time: 79.5, size: 100.0
# sink haha 54 2
# id: 54, src: 2, time: 81.0, size: 100.0
# sink haha 54 1
# id: 54, src: 1, time: 81.0, size: 100.0
# sink haha 54 3
# id: 54, src: 3, time: 81.0, size: 100.0
# sink haha 55 1
# id: 55, src: 1, time: 82.5, size: 100.0
# sink haha 55 2
# id: 55, src: 2, time: 82.5, size: 100.0
# sink haha 55 3
# id: 55, src: 3, time: 82.5, size: 100.0
# sink haha 56 2
# id: 56, src: 2, time: 84.0, size: 100.0
# sink haha 56 1
# id: 56, src: 1, time: 84.0, size: 100.0
# sink haha 56 3
# id: 56, src: 3, time: 84.0, size: 100.0
# sink haha 58 1
# id: 58, src: 1, time: 87.0, size: 100.0
# sink haha 57 2
# id: 57, src: 2, time: 85.5, size: 100.0
# sink haha 57 1
# id: 57, src: 1, time: 85.5, size: 100.0
# sink haha 57 3
# id: 57, src: 3, time: 85.5, size: 100.0
# sink haha 58 3
# id: 58, src: 3, time: 87.0, size: 100.0
# sink haha 58 2
# id: 58, src: 2, time: 87.0, size: 100.0
# sink haha 59 2
# id: 59, src: 2, time: 88.5, size: 100.0
# sink haha 61 1
# id: 61, src: 1, time: 91.5, size: 100.0
# sink haha 59 1
# id: 59, src: 1, time: 88.5, size: 100.0
# sink haha 59 3
# id: 59, src: 3, time: 88.5, size: 100.0
# sink haha 60 1
# id: 60, src: 1, time: 90.0, size: 100.0
# sink haha 62 1
# id: 62, src: 1, time: 93.0, size: 100.0
# sink haha 60 2
# id: 60, src: 2, time: 90.0, size: 100.0
# sink haha 60 3
# id: 60, src: 3, time: 90.0, size: 100.0
# sink haha 61 2
# id: 61, src: 2, time: 91.5, size: 100.0
# sink haha 61 3
# id: 61, src: 3, time: 91.5, size: 100.0
# sink haha 63 1
# id: 63, src: 1, time: 94.5, size: 100.0
# sink haha 62 3
# id: 62, src: 3, time: 93.0, size: 100.0
# sink haha 64 3
# id: 64, src: 3, time: 96.0, size: 100.0
# sink haha 62 2
# id: 62, src: 2, time: 93.0, size: 100.0
# sink haha 64 1
# id: 64, src: 1, time: 96.0, size: 100.0
# sink haha 63 3
# id: 63, src: 3, time: 94.5, size: 100.0
# sink haha 66 3
# id: 66, src: 3, time: 99.0, size: 100.0
# sink haha 63 2
# id: 63, src: 2, time: 94.5, size: 100.0
# sink haha 66 1
# id: 66, src: 1, time: 99.0, size: 100.0
# sink haha 65 1
# id: 65, src: 1, time: 97.5, size: 100.0
# sink haha 65 3
# id: 65, src: 3, time: 97.5, size: 100.0
# sink haha 67 2
# id: 67, src: 2, time: 100.5, size: 100.0
# sink haha 64 2
# id: 64, src: 2, time: 96.0, size: 100.0
# sink haha 67 3
# id: 67, src: 3, time: 100.5, size: 100.0
# sink haha 68 2
# id: 68, src: 2, time: 102.0, size: 100.0
# sink haha 65 2
# id: 65, src: 2, time: 97.5, size: 100.0
# sink haha 67 1
# id: 67, src: 1, time: 100.5, size: 100.0
# sink haha 69 1
# id: 69, src: 1, time: 103.5, size: 100.0
# sink haha 68 3
# id: 68, src: 3, time: 102.0, size: 100.0
# sink haha 66 2
# id: 66, src: 2, time: 99.0, size: 100.0
# sink haha 70 3
# id: 70, src: 3, time: 105.0, size: 100.0
# sink haha 69 3
# id: 69, src: 3, time: 103.5, size: 100.0
# sink haha 68 1
# id: 68, src: 1, time: 102.0, size: 100.0
# sink haha 70 2
# id: 70, src: 2, time: 105.0, size: 100.0
# sink haha 70 1
# id: 70, src: 1, time: 105.0, size: 100.0
# sink haha 69 2
# id: 69, src: 2, time: 103.5, size: 100.0
# sink haha 72 3
# id: 72, src: 3, time: 108.0, size: 100.0
# sink haha 71 3
# id: 71, src: 3, time: 106.5, size: 100.0
# sink haha 71 1
# id: 71, src: 1, time: 106.5, size: 100.0
# sink haha 72 1
# id: 72, src: 1, time: 108.0, size: 100.0
# sink haha 71 2
# id: 71, src: 2, time: 106.5, size: 100.0
# sink haha 72 2
# id: 72, src: 2, time: 108.0, size: 100.0
# sink haha 73 3
# id: 73, src: 3, time: 109.5, size: 100.0
# sink haha 73 2
# id: 73, src: 2, time: 109.5, size: 100.0
# sink haha 73 1
# id: 73, src: 1, time: 109.5, size: 100.0
# sink haha 74 1
# id: 74, src: 1, time: 111.0, size: 100.0
# sink haha 74 3
# id: 74, src: 3, time: 111.0, size: 100.0
# sink haha 76 3
# id: 76, src: 3, time: 114.0, size: 100.0
# sink haha 74 2
# id: 74, src: 2, time: 111.0, size: 100.0
# sink haha 75 3
# id: 75, src: 3, time: 112.5, size: 100.0
# sink haha 77 3
# id: 77, src: 3, time: 115.5, size: 100.0
# sink haha 75 1
# id: 75, src: 1, time: 112.5, size: 100.0
# sink haha 76 1
# id: 76, src: 1, time: 114.0, size: 100.0
# sink haha 75 2
# id: 75, src: 2, time: 112.5, size: 100.0
# sink haha 78 3
# id: 78, src: 3, time: 117.0, size: 100.0
# sink haha 77 1
# id: 77, src: 1, time: 115.5, size: 100.0
# sink haha 76 2
# id: 76, src: 2, time: 114.0, size: 100.0
# sink haha 79 3
# id: 79, src: 3, time: 118.5, size: 100.0
# sink haha 78 1
# id: 78, src: 1, time: 117.0, size: 100.0
# sink haha 77 2
# id: 77, src: 2, time: 115.5, size: 100.0
# sink haha 80 3
# id: 80, src: 3, time: 120.0, size: 100.0
# sink haha 79 1
# id: 79, src: 1, time: 118.5, size: 100.0
# sink haha 81 3
# id: 81, src: 3, time: 121.5, size: 100.0
# sink haha 78 2
# id: 78, src: 2, time: 117.0, size: 100.0
# sink haha 82 3
# id: 82, src: 3, time: 123.0, size: 100.0
# sink haha 83 3
# id: 83, src: 3, time: 124.5, size: 100.0
# sink haha 79 2
# id: 79, src: 2, time: 118.5, size: 100.0
# sink haha 81 1
# id: 81, src: 1, time: 121.5, size: 100.0
# sink haha 80 1
# id: 80, src: 1, time: 120.0, size: 100.0
# sink haha 84 3
# id: 84, src: 3, time: 126.0, size: 100.0
# sink haha 80 2
# id: 80, src: 2, time: 120.0, size: 100.0
# sink haha 82 1
# id: 82, src: 1, time: 123.0, size: 100.0
# sink haha 82 2
# id: 82, src: 2, time: 123.0, size: 100.0
# sink haha 83 1
# id: 83, src: 1, time: 124.5, size: 100.0
# sink haha 81 2
# id: 81, src: 2, time: 121.5, size: 100.0
# sink haha 85 3
# id: 85, src: 3, time: 127.5, size: 100.0
# sink haha 86 3
# id: 86, src: 3, time: 129.0, size: 100.0
# sink haha 84 1
# id: 84, src: 1, time: 126.0, size: 100.0
# sink haha 83 2
# id: 83, src: 2, time: 124.5, size: 100.0
# sink haha 87 3
# id: 87, src: 3, time: 130.5, size: 100.0
# sink haha 84 2
# id: 84, src: 2, time: 126.0, size: 100.0
# sink haha 88 3
# id: 88, src: 3, time: 132.0, size: 100.0
# sink haha 85 1
# id: 85, src: 1, time: 127.5, size: 100.0
# sink haha 85 2
# id: 85, src: 2, time: 127.5, size: 100.0
# sink haha 89 3
# id: 89, src: 3, time: 133.5, size: 100.0
# sink haha 86 2
# id: 86, src: 2, time: 129.0, size: 100.0
# sink haha 86 1
# id: 86, src: 1, time: 129.0, size: 100.0
# sink haha 87 2
# id: 87, src: 2, time: 130.5, size: 100.0
# sink haha 90 3
# id: 90, src: 3, time: 135.0, size: 100.0
# sink haha 87 1
# id: 87, src: 1, time: 130.5, size: 100.0
# sink haha 89 1
# id: 89, src: 1, time: 133.5, size: 100.0
# sink haha 91 3
# id: 91, src: 3, time: 136.5, size: 100.0
# sink haha 88 2
# id: 88, src: 2, time: 132.0, size: 100.0
# sink haha 89 2
# id: 89, src: 2, time: 133.5, size: 100.0
# sink haha 90 2
# id: 90, src: 2, time: 135.0, size: 100.0
# sink haha 88 1
# id: 88, src: 1, time: 132.0, size: 100.0
# sink haha 91 1
# id: 91, src: 1, time: 136.5, size: 100.0
# sink haha 92 3
# id: 92, src: 3, time: 138.0, size: 100.0
# sink haha 91 2
# id: 91, src: 2, time: 136.5, size: 100.0
# sink haha 92 2
# id: 92, src: 2, time: 138.0, size: 100.0
# sink haha 93 1
# id: 93, src: 1, time: 139.5, size: 100.0
# sink haha 93 3
# id: 93, src: 3, time: 139.5, size: 100.0
# sink haha 94 3
# id: 94, src: 3, time: 141.0, size: 100.0
# sink haha 90 1
# id: 90, src: 1, time: 135.0, size: 100.0
# sink haha 93 2
# id: 93, src: 2, time: 139.5, size: 100.0
# sink haha 96 3
# id: 96, src: 3, time: 144.0, size: 100.0
# sink haha 95 3
# id: 95, src: 3, time: 142.5, size: 100.0
# sink haha 92 1
# id: 92, src: 1, time: 138.0, size: 100.0
# sink haha 94 2
# id: 94, src: 2, time: 141.0, size: 100.0
# sink haha 96 1
# id: 96, src: 1, time: 144.0, size: 100.0
# sink haha 95 2
# id: 95, src: 2, time: 142.5, size: 100.0
# sink haha 97 3
# id: 97, src: 3, time: 145.5, size: 100.0
# sink haha 97 1
# id: 97, src: 1, time: 145.5, size: 100.0
# sink haha 96 2
# id: 96, src: 2, time: 144.0, size: 100.0
# sink haha 98 1
# id: 98, src: 1, time: 147.0, size: 100.0
# sink haha 94 1
# id: 94, src: 1, time: 141.0, size: 100.0
# sink haha 99 1
# id: 99, src: 1, time: 148.5, size: 100.0
# sink haha 98 3
# id: 98, src: 3, time: 147.0, size: 100.0
# sink haha 95 1
# id: 95, src: 1, time: 142.5, size: 100.0
# sink haha 100 3
# id: 100, src: 3, time: 150.0, size: 100.0
# sink haha 97 2
# id: 97, src: 2, time: 145.5, size: 100.0
# sink haha 98 2
# id: 98, src: 2, time: 147.0, size: 100.0
# sink haha 99 2
# id: 99, src: 2, time: 148.5, size: 100.0
# sink haha 99 3
# id: 99, src: 3, time: 148.5, size: 100.0
# sink haha 100 1
# id: 100, src: 1, time: 150.0, size: 100.0
# sink haha 100 2
# id: 100, src: 2, time: 150.0, size: 100.0
# sink haha 101 1
# id: 101, src: 1, time: 151.5, size: 100.0
# sink haha 101 2
# id: 101, src: 2, time: 151.5, size: 100.0
# sink haha 102 3
# id: 102, src: 3, time: 153.0, size: 100.0
# sink haha 101 3
# id: 101, src: 3, time: 151.5, size: 100.0
# sink haha 102 1
# id: 102, src: 1, time: 153.0, size: 100.0
# sink haha 102 2
# id: 102, src: 2, time: 153.0, size: 100.0
# sink haha 103 3
# id: 103, src: 3, time: 154.5, size: 100.0
# sink haha 104 3
# id: 104, src: 3, time: 156.0, size: 100.0
# sink haha 103 2
# id: 103, src: 2, time: 154.5, size: 100.0
# sink haha 105 3
# id: 105, src: 3, time: 157.5, size: 100.0
# sink haha 103 1
# id: 103, src: 1, time: 154.5, size: 100.0
# sink haha 104 2
# id: 104, src: 2, time: 156.0, size: 100.0
# sink haha 104 1
# id: 104, src: 1, time: 156.0, size: 100.0
# sink haha 107 3
# id: 107, src: 3, time: 160.5, size: 100.0
# sink haha 106 3
# id: 106, src: 3, time: 159.0, size: 100.0
# sink haha 105 2
# id: 105, src: 2, time: 157.5, size: 100.0
# sink haha 106 1
# id: 106, src: 1, time: 159.0, size: 100.0
# sink haha 105 1
# id: 105, src: 1, time: 157.5, size: 100.0
# sink haha 106 2
# id: 106, src: 2, time: 159.0, size: 100.0
# sink haha 107 2
# id: 107, src: 2, time: 160.5, size: 100.0
# sink haha 108 3
# id: 108, src: 3, time: 162.0, size: 100.0
# sink haha 107 1
# id: 107, src: 1, time: 160.5, size: 100.0
# sink haha 108 2
# id: 108, src: 2, time: 162.0, size: 100.0
# sink haha 109 2
# id: 109, src: 2, time: 163.5, size: 100.0
# sink haha 109 3
# id: 109, src: 3, time: 163.5, size: 100.0
# sink haha 108 1
# id: 108, src: 1, time: 162.0, size: 100.0
# sink haha 110 3
# id: 110, src: 3, time: 165.0, size: 100.0
# sink haha 110 2
# id: 110, src: 2, time: 165.0, size: 100.0
# sink haha 109 1
# id: 109, src: 1, time: 163.5, size: 100.0
# sink haha 111 2
# id: 111, src: 2, time: 166.5, size: 100.0
# sink haha 110 1
# id: 110, src: 1, time: 165.0, size: 100.0
# sink haha 111 3
# id: 111, src: 3, time: 166.5, size: 100.0
# sink haha 113 1
# id: 113, src: 1, time: 169.5, size: 100.0
# sink haha 112 2
# id: 112, src: 2, time: 168.0, size: 100.0
# sink haha 111 1
# id: 111, src: 1, time: 166.5, size: 100.0
# sink haha 112 3
# id: 112, src: 3, time: 168.0, size: 100.0
# sink haha 113 3
# id: 113, src: 3, time: 169.5, size: 100.0
# sink haha 112 1
# id: 112, src: 1, time: 168.0, size: 100.0
# sink haha 114 3
# id: 114, src: 3, time: 171.0, size: 100.0
# sink haha 115 1
# id: 115, src: 1, time: 172.5, size: 100.0
# sink haha 113 2
# id: 113, src: 2, time: 169.5, size: 100.0
# sink haha 114 2
# id: 114, src: 2, time: 171.0, size: 100.0
# sink haha 116 3
# id: 116, src: 3, time: 174.0, size: 100.0
# sink haha 115 3
# id: 115, src: 3, time: 172.5, size: 100.0
# sink haha 114 1
# id: 114, src: 1, time: 171.0, size: 100.0
# sink haha 117 3
# id: 117, src: 3, time: 175.5, size: 100.0
# sink haha 117 1
# id: 117, src: 1, time: 175.5, size: 100.0
# sink haha 115 2
# id: 115, src: 2, time: 172.5, size: 100.0
# sink haha 118 3
# id: 118, src: 3, time: 177.0, size: 100.0
# sink haha 116 1
# id: 116, src: 1, time: 174.0, size: 100.0
# sink haha 116 2
# id: 116, src: 2, time: 174.0, size: 100.0
# sink haha 120 3
# id: 120, src: 3, time: 180.0, size: 100.0
# sink haha 118 1
# id: 118, src: 1, time: 177.0, size: 100.0
# sink haha 119 3
# id: 119, src: 3, time: 178.5, size: 100.0
# sink haha 120 1
# id: 120, src: 1, time: 180.0, size: 100.0
# sink haha 117 2
# id: 117, src: 2, time: 175.5, size: 100.0
# sink haha 119 1
# id: 119, src: 1, time: 178.5, size: 100.0
# sink haha 121 3
# id: 121, src: 3, time: 181.5, size: 100.0
# sink haha 118 2
# id: 118, src: 2, time: 177.0, size: 100.0
# sink haha 122 3
# id: 122, src: 3, time: 183.0, size: 100.0
# sink haha 121 1
# id: 121, src: 1, time: 181.5, size: 100.0
# sink haha 123 3
# id: 123, src: 3, time: 184.5, size: 100.0
# sink haha 119 2
# id: 119, src: 2, time: 178.5, size: 100.0
# sink haha 122 1
# id: 122, src: 1, time: 183.0, size: 100.0
# sink haha 124 3
# id: 124, src: 3, time: 186.0, size: 100.0
# sink haha 123 1
# id: 123, src: 1, time: 184.5, size: 100.0
# sink haha 120 2
# id: 120, src: 2, time: 180.0, size: 100.0
# sink haha 125 3
# id: 125, src: 3, time: 187.5, size: 100.0
# sink haha 121 2
# id: 121, src: 2, time: 181.5, size: 100.0
# sink haha 122 2
# id: 122, src: 2, time: 183.0, size: 100.0
# sink haha 124 1
# id: 124, src: 1, time: 186.0, size: 100.0
# sink haha 125 1
# id: 125, src: 1, time: 187.5, size: 100.0
# sink haha 127 3
# id: 127, src: 3, time: 190.5, size: 100.0
# sink haha 126 3
# id: 126, src: 3, time: 189.0, size: 100.0
# sink haha 123 2
# id: 123, src: 2, time: 184.5, size: 100.0
# sink haha 128 3
# id: 128, src: 3, time: 192.0, size: 100.0
# sink haha 129 3
# id: 129, src: 3, time: 193.5, size: 100.0
# sink haha 124 2
# id: 124, src: 2, time: 186.0, size: 100.0
# sink haha 127 1
# id: 127, src: 1, time: 190.5, size: 100.0
# sink haha 126 1
# id: 126, src: 1, time: 189.0, size: 100.0
# sink haha 125 2
# id: 125, src: 2, time: 187.5, size: 100.0
# sink haha 130 3
# id: 130, src: 3, time: 195.0, size: 100.0
# sink haha 126 2
# id: 126, src: 2, time: 189.0, size: 100.0
# sink haha 127 2
# id: 127, src: 2, time: 190.5, size: 100.0
# sink haha 130 1
# id: 130, src: 1, time: 195.0, size: 100.0
# sink haha 130 2
# id: 130, src: 2, time: 195.0, size: 100.0
# sink haha 128 1
# id: 128, src: 1, time: 192.0, size: 100.0
# sink haha 129 1
# id: 129, src: 1, time: 193.5, size: 100.0
# sink haha 131 1
# id: 131, src: 1, time: 196.5, size: 100.0
# sink haha 131 3
# id: 131, src: 3, time: 196.5, size: 100.0
# sink haha 128 2
# id: 128, src: 2, time: 192.0, size: 100.0
# sink haha 132 3
# id: 132, src: 3, time: 198.0, size: 100.0
# sink haha 129 2
# id: 129, src: 2, time: 193.5, size: 100.0
# sink haha 132 2
# id: 132, src: 2, time: 198.0, size: 100.0
# sink haha 134 1
# id: 134, src: 1, time: 201.0, size: 100.0
# sink haha 133 3
# id: 133, src: 3, time: 199.5, size: 100.0
# sink haha 131 2
# id: 131, src: 2, time: 196.5, size: 100.0
# sink haha 135 1
# id: 135, src: 1, time: 202.5, size: 100.0
# sink haha 134 3
# id: 134, src: 3, time: 201.0, size: 100.0
# sink haha 132 1
# id: 132, src: 1, time: 198.0, size: 100.0
# sink haha 136 2
# id: 136, src: 2, time: 204.0, size: 100.0
# sink haha 133 1
# id: 133, src: 1, time: 199.5, size: 100.0
# sink haha 135 3
# id: 135, src: 3, time: 202.5, size: 100.0
# sink haha 133 2
# id: 133, src: 2, time: 199.5, size: 100.0
# sink haha 134 2
# id: 134, src: 2, time: 201.0, size: 100.0
# sink haha 138 1
# id: 138, src: 1, time: 207.0, size: 100.0
# sink haha 137 3
# id: 137, src: 3, time: 205.5, size: 100.0
# sink haha 136 3
# id: 136, src: 3, time: 204.0, size: 100.0
# sink haha 136 1
# id: 136, src: 1, time: 204.0, size: 100.0
# sink haha 138 3
# id: 138, src: 3, time: 207.0, size: 100.0
# sink haha 135 2
# id: 135, src: 2, time: 202.5, size: 100.0
# sink haha 137 1
# id: 137, src: 1, time: 205.5, size: 100.0
# sink haha 137 2
# id: 137, src: 2, time: 205.5, size: 100.0
# sink haha 140 1
# id: 140, src: 1, time: 210.0, size: 100.0
# sink haha 139 3
# id: 139, src: 3, time: 208.5, size: 100.0
# sink haha 138 2
# id: 138, src: 2, time: 207.0, size: 100.0
# sink haha 141 2
# id: 141, src: 2, time: 211.5, size: 100.0
# sink haha 139 1
# id: 139, src: 1, time: 208.5, size: 100.0
# sink haha 142 1
# id: 142, src: 1, time: 213.0, size: 100.0
# sink haha 139 2
# id: 139, src: 2, time: 208.5, size: 100.0
# sink haha 140 3
# id: 140, src: 3, time: 210.0, size: 100.0
# sink haha 140 2
# id: 140, src: 2, time: 210.0, size: 100.0
# sink haha 144 2
# id: 144, src: 2, time: 216.0, size: 100.0
# sink haha 141 3
# id: 141, src: 3, time: 211.5, size: 100.0
# sink haha 142 2
# id: 142, src: 2, time: 213.0, size: 100.0
# sink haha 143 3
# id: 143, src: 3, time: 214.5, size: 100.0
# sink haha 141 1
# id: 141, src: 1, time: 211.5, size: 100.0
# sink haha 143 2
# id: 143, src: 2, time: 214.5, size: 100.0
# sink haha 145 1
# id: 145, src: 1, time: 217.5, size: 100.0
# sink haha 142 3
# id: 142, src: 3, time: 213.0, size: 100.0
# sink haha 146 2
# id: 146, src: 2, time: 219.0, size: 100.0
# sink haha 143 1
# id: 143, src: 1, time: 214.5, size: 100.0
# sink haha 145 2
# id: 145, src: 2, time: 217.5, size: 100.0
# sink haha 147 1
# id: 147, src: 1, time: 220.5, size: 100.0
# sink haha 144 1
# id: 144, src: 1, time: 216.0, size: 100.0
# sink haha 147 3
# id: 147, src: 3, time: 220.5, size: 100.0
# sink haha 144 3
# id: 144, src: 3, time: 216.0, size: 100.0
# sink haha 145 3
# id: 145, src: 3, time: 217.5, size: 100.0
# sink haha 147 2
# id: 147, src: 2, time: 220.5, size: 100.0
# sink haha 148 1
# id: 148, src: 1, time: 222.0, size: 100.0
# sink haha 146 1
# id: 146, src: 1, time: 219.0, size: 100.0
# sink haha 148 2
# id: 148, src: 2, time: 222.0, size: 100.0
# sink haha 146 3
# id: 146, src: 3, time: 219.0, size: 100.0
# sink haha 149 1
# id: 149, src: 1, time: 223.5, size: 100.0
# sink haha 149 3
# id: 149, src: 3, time: 223.5, size: 100.0
# sink haha 149 2
# id: 149, src: 2, time: 223.5, size: 100.0
# sink haha 150 1
# id: 150, src: 1, time: 225.0, size: 100.0
# sink haha 150 3
# id: 150, src: 3, time: 225.0, size: 100.0
# sink haha 152 2
# id: 152, src: 2, time: 228.0, size: 100.0
# sink haha 148 3
# id: 148, src: 3, time: 222.0, size: 100.0
# sink haha 151 1
# id: 151, src: 1, time: 226.5, size: 100.0
# sink haha 150 2
# id: 150, src: 2, time: 225.0, size: 100.0
# sink haha 154 2
# id: 154, src: 2, time: 231.0, size: 100.0
# sink haha 152 1
# id: 152, src: 1, time: 228.0, size: 100.0
# sink haha 152 3
# id: 152, src: 3, time: 228.0, size: 100.0
# sink haha 151 2
# id: 151, src: 2, time: 226.5, size: 100.0
# sink haha 155 2
# id: 155, src: 2, time: 232.5, size: 100.0
# sink haha 154 1
# id: 154, src: 1, time: 231.0, size: 100.0
# sink haha 153 1
# id: 153, src: 1, time: 229.5, size: 100.0
# sink haha 155 1
# id: 155, src: 1, time: 232.5, size: 100.0
# sink haha 151 3
# id: 151, src: 3, time: 226.5, size: 100.0
# sink haha 157 2
# id: 157, src: 2, time: 235.5, size: 100.0
# sink haha 153 2
# id: 153, src: 2, time: 229.5, size: 100.0
# sink haha 155 3
# id: 155, src: 3, time: 232.5, size: 100.0
# sink haha 158 2
# id: 158, src: 2, time: 237.0, size: 100.0
# sink haha 153 3
# id: 153, src: 3, time: 229.5, size: 100.0
# sink haha 156 1
# id: 156, src: 1, time: 234.0, size: 100.0
# sink haha 154 3
# id: 154, src: 3, time: 231.0, size: 100.0
# sink haha 160 2
# id: 160, src: 2, time: 240.0, size: 100.0
# sink haha 156 3
# id: 156, src: 3, time: 234.0, size: 100.0
# sink haha 161 1
# id: 161, src: 1, time: 241.5, size: 100.0
# sink haha 157 1
# id: 157, src: 1, time: 235.5, size: 100.0
# sink haha 161 2
# id: 161, src: 2, time: 241.5, size: 100.0
# sink haha 156 2
# id: 156, src: 2, time: 234.0, size: 100.0
# sink haha 162 2
# id: 162, src: 2, time: 243.0, size: 100.0
# sink haha 158 1
# id: 158, src: 1, time: 237.0, size: 100.0
# sink haha 157 3
# id: 157, src: 3, time: 235.5, size: 100.0
# sink haha 163 2
# id: 163, src: 2, time: 244.5, size: 100.0
# sink haha 158 3
# id: 158, src: 3, time: 237.0, size: 100.0
# sink haha 163 1
# id: 163, src: 1, time: 244.5, size: 100.0
# sink haha 159 1
# id: 159, src: 1, time: 238.5, size: 100.0
# sink haha 159 3
# id: 159, src: 3, time: 238.5, size: 100.0
# sink haha 160 1
# id: 160, src: 1, time: 240.0, size: 100.0
# sink haha 161 3
# id: 161, src: 3, time: 241.5, size: 100.0
# sink haha 159 2
# id: 159, src: 2, time: 238.5, size: 100.0
# sink haha 164 2
# id: 164, src: 2, time: 246.0, size: 100.0
# sink haha 165 1
# id: 165, src: 1, time: 247.5, size: 100.0
# sink haha 160 3
# id: 160, src: 3, time: 240.0, size: 100.0
# sink haha 162 1
# id: 162, src: 1, time: 243.0, size: 100.0
# sink haha 165 2
# id: 165, src: 2, time: 247.5, size: 100.0
# sink haha 162 3
# id: 162, src: 3, time: 243.0, size: 100.0
# sink haha 166 2
# id: 166, src: 2, time: 249.0, size: 100.0
# sink haha 168 1
# id: 168, src: 1, time: 252.0, size: 100.0
# sink haha 165 3
# id: 165, src: 3, time: 247.5, size: 100.0
# sink haha 167 2
# id: 167, src: 2, time: 250.5, size: 100.0
# sink haha 163 3
# id: 163, src: 3, time: 244.5, size: 100.0
# sink haha 164 1
# id: 164, src: 1, time: 246.0, size: 100.0
# sink haha 164 3
# id: 164, src: 3, time: 246.0, size: 100.0
# sink haha 170 1
# id: 170, src: 1, time: 255.0, size: 100.0
# sink haha 169 2
# id: 169, src: 2, time: 253.5, size: 100.0
# sink haha 166 3
# id: 166, src: 3, time: 249.0, size: 100.0
# sink haha 168 3
# id: 168, src: 3, time: 252.0, size: 100.0
# sink haha 170 2
# id: 170, src: 2, time: 255.0, size: 100.0
# sink haha 167 3
# id: 167, src: 3, time: 250.5, size: 100.0
# sink haha 166 1
# id: 166, src: 1, time: 249.0, size: 100.0
# sink haha 172 1
# id: 172, src: 1, time: 258.0, size: 100.0
# sink haha 169 3
# id: 169, src: 3, time: 253.5, size: 100.0
# sink haha 171 2
# id: 171, src: 2, time: 256.5, size: 100.0
# sink haha 167 1
# id: 167, src: 1, time: 250.5, size: 100.0
# sink haha 170 3
# id: 170, src: 3, time: 255.0, size: 100.0
# sink haha 173 2
# id: 173, src: 2, time: 259.5, size: 100.0
# sink haha 174 2
# id: 174, src: 2, time: 261.0, size: 100.0
# sink haha 169 1
# id: 169, src: 1, time: 253.5, size: 100.0
# sink haha 171 3
# id: 171, src: 3, time: 256.5, size: 100.0
# sink haha 172 3
# id: 172, src: 3, time: 258.0, size: 100.0
# sink haha 175 1
# id: 175, src: 1, time: 262.5, size: 100.0
# sink haha 168 2
# id: 168, src: 2, time: 252.0, size: 100.0
# sink haha 175 2
# id: 175, src: 2, time: 262.5, size: 100.0
# sink haha 176 1
# id: 176, src: 1, time: 264.0, size: 100.0
# sink haha 171 1
# id: 171, src: 1, time: 256.5, size: 100.0
# sink haha 173 3
# id: 173, src: 3, time: 259.5, size: 100.0
# sink haha 178 1
# id: 178, src: 1, time: 267.0, size: 100.0
# sink haha 174 3
# id: 174, src: 3, time: 261.0, size: 100.0
# sink haha 179 1
# id: 179, src: 1, time: 268.5, size: 100.0
# sink haha 177 2
# id: 177, src: 2, time: 265.5, size: 100.0
# sink haha 173 1
# id: 173, src: 1, time: 259.5, size: 100.0
# sink haha 175 3
# id: 175, src: 3, time: 262.5, size: 100.0
# sink haha 180 1
# id: 180, src: 1, time: 270.0, size: 100.0
# sink haha 172 2
# id: 172, src: 2, time: 258.0, size: 100.0
# sink haha 181 1
# id: 181, src: 1, time: 271.5, size: 100.0
# sink haha 176 3
# id: 176, src: 3, time: 264.0, size: 100.0
# sink haha 174 1
# id: 174, src: 1, time: 261.0, size: 100.0
# sink haha 182 1
# id: 182, src: 1, time: 273.0, size: 100.0
# sink haha 178 3
# id: 178, src: 3, time: 267.0, size: 100.0
# sink haha 179 2
# id: 179, src: 2, time: 268.5, size: 100.0
# sink haha 177 3
# id: 177, src: 3, time: 265.5, size: 100.0
# sink haha 183 1
# id: 183, src: 1, time: 274.5, size: 100.0
# sink haha 180 2
# id: 180, src: 2, time: 270.0, size: 100.0
# sink haha 180 3
# id: 180, src: 3, time: 270.0, size: 100.0
# sink haha 179 3
# id: 179, src: 3, time: 268.5, size: 100.0
# sink haha 177 1
# id: 177, src: 1, time: 265.5, size: 100.0
# sink haha 184 1
# id: 184, src: 1, time: 276.0, size: 100.0
# sink haha 181 2
# id: 181, src: 2, time: 271.5, size: 100.0
# sink haha 182 3
# id: 182, src: 3, time: 273.0, size: 100.0
# sink haha 176 2
# id: 176, src: 2, time: 264.0, size: 100.0
# sink haha 182 2
# id: 182, src: 2, time: 273.0, size: 100.0
# sink haha 181 3
# id: 181, src: 3, time: 271.5, size: 100.0
# sink haha 183 2
# id: 183, src: 2, time: 274.5, size: 100.0
# sink haha 187 1
# id: 187, src: 1, time: 280.5, size: 100.0
# sink haha 185 3
# id: 185, src: 3, time: 277.5, size: 100.0
# sink haha 178 2
# id: 178, src: 2, time: 267.0, size: 100.0
# sink haha 184 2
# id: 184, src: 2, time: 276.0, size: 100.0
# sink haha 186 3
# id: 186, src: 3, time: 279.0, size: 100.0
# sink haha 183 3
# id: 183, src: 3, time: 274.5, size: 100.0
# sink haha 187 3
# id: 187, src: 3, time: 280.5, size: 100.0
# sink haha 188 1
# id: 188, src: 1, time: 282.0, size: 100.0
# sink haha 185 2
# id: 185, src: 2, time: 277.5, size: 100.0
# sink haha 184 3
# id: 184, src: 3, time: 276.0, size: 100.0
# sink haha 190 1
# id: 190, src: 1, time: 285.0, size: 100.0
# sink haha 185 1
# id: 185, src: 1, time: 277.5, size: 100.0
# sink haha 186 2
# id: 186, src: 2, time: 279.0, size: 100.0
# sink haha 188 3
# id: 188, src: 3, time: 282.0, size: 100.0
# sink haha 187 2
# id: 187, src: 2, time: 280.5, size: 100.0
# sink haha 188 2
# id: 188, src: 2, time: 282.0, size: 100.0
# sink haha 186 1
# id: 186, src: 1, time: 279.0, size: 100.0
# sink haha 189 3
# id: 189, src: 3, time: 283.5, size: 100.0
# sink haha 189 2
# id: 189, src: 2, time: 283.5, size: 100.0
# sink haha 193 1
# id: 193, src: 1, time: 289.5, size: 100.0
# sink haha 190 2
# id: 190, src: 2, time: 285.0, size: 100.0
# sink haha 190 3
# id: 190, src: 3, time: 285.0, size: 100.0
# sink haha 194 1
# id: 194, src: 1, time: 291.0, size: 100.0
# sink haha 189 1
# id: 189, src: 1, time: 283.5, size: 100.0
# sink haha 191 3
# id: 191, src: 3, time: 286.5, size: 100.0
# sink haha 193 2
# id: 193, src: 2, time: 289.5, size: 100.0
# sink haha 195 1
# id: 195, src: 1, time: 292.5, size: 100.0
# sink haha 191 1
# id: 191, src: 1, time: 286.5, size: 100.0
# sink haha 194 2
# id: 194, src: 2, time: 291.0, size: 100.0
# sink haha 192 3
# id: 192, src: 3, time: 288.0, size: 100.0
# sink haha 193 3
# id: 193, src: 3, time: 289.5, size: 100.0
# sink haha 195 2
# id: 195, src: 2, time: 292.5, size: 100.0
# sink haha 191 2
# id: 191, src: 2, time: 286.5, size: 100.0
# sink haha 196 1
# id: 196, src: 1, time: 294.0, size: 100.0
# sink haha 192 1
# id: 192, src: 1, time: 288.0, size: 100.0
# sink haha 192 2
# id: 192, src: 2, time: 288.0, size: 100.0
# sink haha 196 2
# id: 196, src: 2, time: 294.0, size: 100.0
# sink haha 197 1
# id: 197, src: 1, time: 295.5, size: 100.0
# sink haha 197 2
# id: 197, src: 2, time: 295.5, size: 100.0
# sink haha 194 3
# id: 194, src: 3, time: 291.0, size: 100.0
# sink haha 198 1
# id: 198, src: 1, time: 297.0, size: 100.0
# sink haha 199 1
# id: 199, src: 1, time: 298.5, size: 100.0
# sink haha 198 2
# id: 198, src: 2, time: 297.0, size: 100.0
# sink haha 196 3
# id: 196, src: 3, time: 294.0, size: 100.0
# sink haha 195 3
# id: 195, src: 3, time: 292.5, size: 100.0
# sink haha 197 3
# id: 197, src: 3, time: 295.5, size: 100.0
# sink haha 201 1
# id: 201, src: 1, time: 301.5, size: 100.0
# sink haha 199 2
# id: 199, src: 2, time: 298.5, size: 100.0
# sink haha 200 2
# id: 200, src: 2, time: 300.0, size: 100.0
# sink haha 200 1
# id: 200, src: 1, time: 300.0, size: 100.0
# sink haha 198 3
# id: 198, src: 3, time: 297.0, size: 100.0
# sink haha 202 1
# id: 202, src: 1, time: 303.0, size: 100.0
# sink haha 201 2
# id: 201, src: 2, time: 301.5, size: 100.0
# sink haha 199 3
# id: 199, src: 3, time: 298.5, size: 100.0
# sink haha 202 2
# id: 202, src: 2, time: 303.0, size: 100.0
# sink haha 203 1
# id: 203, src: 1, time: 304.5, size: 100.0
# sink haha 200 3
# id: 200, src: 3, time: 300.0, size: 100.0
# sink haha 203 2
# id: 203, src: 2, time: 304.5, size: 100.0
# sink haha 206 1
# id: 206, src: 1, time: 309.0, size: 100.0
# sink haha 204 1
# id: 204, src: 1, time: 306.0, size: 100.0
# sink haha 204 2
# id: 204, src: 2, time: 306.0, size: 100.0
# sink haha 201 3
# id: 201, src: 3, time: 301.5, size: 100.0
# sink haha 205 1
# id: 205, src: 1, time: 307.5, size: 100.0
# sink haha 205 2
# id: 205, src: 2, time: 307.5, size: 100.0
# sink haha 207 2
# id: 207, src: 2, time: 310.5, size: 100.0
# sink haha 207 1
# id: 207, src: 1, time: 310.5, size: 100.0
# sink haha 208 1
# id: 208, src: 1, time: 312.0, size: 100.0
# sink haha 202 3
# id: 202, src: 3, time: 303.0, size: 100.0
# sink haha 206 2
# id: 206, src: 2, time: 309.0, size: 100.0
# sink haha 209 1
# id: 209, src: 1, time: 313.5, size: 100.0
# sink haha 203 3
# id: 203, src: 3, time: 304.5, size: 100.0
# sink haha 208 2
# id: 208, src: 2, time: 312.0, size: 100.0
# sink haha 209 2
# id: 209, src: 2, time: 313.5, size: 100.0
# sink haha 210 1
# id: 210, src: 1, time: 315.0, size: 100.0
# sink haha 211 1
# id: 211, src: 1, time: 316.5, size: 100.0
# sink haha 204 3
# id: 204, src: 3, time: 306.0, size: 100.0
# sink haha 210 2
# id: 210, src: 2, time: 315.0, size: 100.0
# sink haha 212 1
# id: 212, src: 1, time: 318.0, size: 100.0
# sink haha 211 2
# id: 211, src: 2, time: 316.5, size: 100.0
# sink haha 205 3
# id: 205, src: 3, time: 307.5, size: 100.0
# sink haha 213 1
# id: 213, src: 1, time: 319.5, size: 100.0
# sink haha 206 3
# id: 206, src: 3, time: 309.0, size: 100.0
# sink haha 212 2
# id: 212, src: 2, time: 318.0, size: 100.0
# sink haha 214 1
# id: 214, src: 1, time: 321.0, size: 100.0
# sink haha 213 2
# id: 213, src: 2, time: 319.5, size: 100.0
# sink haha 207 3
# id: 207, src: 3, time: 310.5, size: 100.0
# sink haha 215 1
# id: 215, src: 1, time: 322.5, size: 100.0
# sink haha 209 3
# id: 209, src: 3, time: 313.5, size: 100.0
# sink haha 208 3
# id: 208, src: 3, time: 312.0, size: 100.0
# sink haha 214 2
# id: 214, src: 2, time: 321.0, size: 100.0
# sink haha 216 1
# id: 216, src: 1, time: 324.0, size: 100.0
# sink haha 215 2
# id: 215, src: 2, time: 322.5, size: 100.0
# sink haha 217 1
# id: 217, src: 1, time: 325.5, size: 100.0
# sink haha 216 2
# id: 216, src: 2, time: 324.0, size: 100.0
# sink haha 210 3
# id: 210, src: 3, time: 315.0, size: 100.0
# sink haha 218 1
# id: 218, src: 1, time: 327.0, size: 100.0
# sink haha 217 2
# id: 217, src: 2, time: 325.5, size: 100.0
# sink haha 211 3
# id: 211, src: 3, time: 316.5, size: 100.0
# sink haha 221 1
# id: 221, src: 1, time: 331.5, size: 100.0
# sink haha 219 1
# id: 219, src: 1, time: 328.5, size: 100.0
# sink haha 212 3
# id: 212, src: 3, time: 318.0, size: 100.0
# sink haha 218 2
# id: 218, src: 2, time: 327.0, size: 100.0
# sink haha 220 1
# id: 220, src: 1, time: 330.0, size: 100.0
# sink haha 223 1
# id: 223, src: 1, time: 334.5, size: 100.0
# sink haha 213 3
# id: 213, src: 3, time: 319.5, size: 100.0
# sink haha 214 3
# id: 214, src: 3, time: 321.0, size: 100.0
# sink haha 219 2
# id: 219, src: 2, time: 328.5, size: 100.0
# sink haha 220 2
# id: 220, src: 2, time: 330.0, size: 100.0
# sink haha 224 1
# id: 224, src: 1, time: 336.0, size: 100.0
# sink haha 215 3
# id: 215, src: 3, time: 322.5, size: 100.0
# sink haha 216 3
# id: 216, src: 3, time: 324.0, size: 100.0
# sink haha 222 1
# id: 222, src: 1, time: 333.0, size: 100.0
# sink haha 225 1
# id: 225, src: 1, time: 337.5, size: 100.0
# sink haha 221 2
# id: 221, src: 2, time: 331.5, size: 100.0
# sink haha 217 3
# id: 217, src: 3, time: 325.5, size: 100.0
# sink haha 218 3
# id: 218, src: 3, time: 327.0, size: 100.0
# sink haha 222 2
# id: 222, src: 2, time: 333.0, size: 100.0
# sink haha 226 1
# id: 226, src: 1, time: 339.0, size: 100.0
# sink haha 223 2
# id: 223, src: 2, time: 334.5, size: 100.0
# sink haha 219 3
# id: 219, src: 3, time: 328.5, size: 100.0
# sink haha 227 1
# id: 227, src: 1, time: 340.5, size: 100.0
# sink haha 224 2
# id: 224, src: 2, time: 336.0, size: 100.0
# sink haha 220 3
# id: 220, src: 3, time: 330.0, size: 100.0
# sink haha 225 2
# id: 225, src: 2, time: 337.5, size: 100.0
# sink haha 228 1
# id: 228, src: 1, time: 342.0, size: 100.0
# sink haha 222 3
# id: 222, src: 3, time: 333.0, size: 100.0
# sink haha 226 2
# id: 226, src: 2, time: 339.0, size: 100.0
# sink haha 229 1
# id: 229, src: 1, time: 343.5, size: 100.0
# sink haha 221 3
# id: 221, src: 3, time: 331.5, size: 100.0
# sink haha 223 3
# id: 223, src: 3, time: 334.5, size: 100.0
# sink haha 227 2
# id: 227, src: 2, time: 340.5, size: 100.0
# sink haha 231 1
# id: 231, src: 1, time: 346.5, size: 100.0
# sink haha 230 1
# id: 230, src: 1, time: 345.0, size: 100.0
# sink haha 224 3
# id: 224, src: 3, time: 336.0, size: 100.0
# sink haha 225 3
# id: 225, src: 3, time: 337.5, size: 100.0
# sink haha 228 2
# id: 228, src: 2, time: 342.0, size: 100.0
# sink haha 232 1
# id: 232, src: 1, time: 348.0, size: 100.0
# sink haha 229 2
# id: 229, src: 2, time: 343.5, size: 100.0
# sink haha 226 3
# id: 226, src: 3, time: 339.0, size: 100.0
# sink haha 230 2
# id: 230, src: 2, time: 345.0, size: 100.0
# sink haha 233 1
# id: 233, src: 1, time: 349.5, size: 100.0
# sink haha 228 3
# id: 228, src: 3, time: 342.0, size: 100.0
# sink haha 238 2
# id: 238, src: 2, time: 357.0, size: 100.0
# sink haha 234 1
# id: 234, src: 1, time: 351.0, size: 100.0
# sink haha 227 3
# id: 227, src: 3, time: 340.5, size: 100.0
# sink haha 231 2
# id: 231, src: 2, time: 346.5, size: 100.0
# sink haha 232 2
# id: 232, src: 2, time: 348.0, size: 100.0
# sink haha 233 2
# id: 233, src: 2, time: 349.5, size: 100.0
# sink haha 237 1
# id: 237, src: 1, time: 355.5, size: 100.0
# sink haha 240 2
# id: 240, src: 2, time: 360.0, size: 100.0
# sink haha 235 1
# id: 235, src: 1, time: 352.5, size: 100.0
# sink haha 234 2
# id: 234, src: 2, time: 351.0, size: 100.0
# sink haha 232 3
# id: 232, src: 3, time: 348.0, size: 100.0
# sink haha 229 3
# id: 229, src: 3, time: 343.5, size: 100.0
# sink haha 235 2
# id: 235, src: 2, time: 352.5, size: 100.0
# sink haha 238 1
# id: 238, src: 1, time: 357.0, size: 100.0
# sink haha 233 3
# id: 233, src: 3, time: 349.5, size: 100.0
# sink haha 230 3
# id: 230, src: 3, time: 345.0, size: 100.0
# sink haha 236 2
# id: 236, src: 2, time: 354.0, size: 100.0
# sink haha 236 1
# id: 236, src: 1, time: 354.0, size: 100.0
# sink haha 237 2
# id: 237, src: 2, time: 355.5, size: 100.0
# sink haha 237 3
# id: 237, src: 3, time: 355.5, size: 100.0
# sink haha 239 2
# id: 239, src: 2, time: 358.5, size: 100.0
# sink haha 231 3
# id: 231, src: 3, time: 346.5, size: 100.0
# sink haha 240 1
# id: 240, src: 1, time: 360.0, size: 100.0
# sink haha 239 1
# id: 239, src: 1, time: 358.5, size: 100.0
# sink haha 238 3
# id: 238, src: 3, time: 357.0, size: 100.0
# sink haha 242 1
# id: 242, src: 1, time: 363.0, size: 100.0
# sink haha 241 2
# id: 241, src: 2, time: 361.5, size: 100.0
# sink haha 234 3
# id: 234, src: 3, time: 351.0, size: 100.0
# sink haha 242 2
# id: 242, src: 2, time: 363.0, size: 100.0
# sink haha 243 1
# id: 243, src: 1, time: 364.5, size: 100.0
# sink haha 239 3
# id: 239, src: 3, time: 358.5, size: 100.0
# sink haha 247 2
# id: 247, src: 2, time: 370.5, size: 100.0
# sink haha 241 1
# id: 241, src: 1, time: 361.5, size: 100.0
# sink haha 235 3
# id: 235, src: 3, time: 352.5, size: 100.0
# sink haha 240 3
# id: 240, src: 3, time: 360.0, size: 100.0
# sink haha 243 2
# id: 243, src: 2, time: 364.5, size: 100.0
# sink haha 236 3
# id: 236, src: 3, time: 354.0, size: 100.0
# sink haha 244 2
# id: 244, src: 2, time: 366.0, size: 100.0
# sink haha 244 1
# id: 244, src: 1, time: 366.0, size: 100.0
# sink haha 241 3
# id: 241, src: 3, time: 361.5, size: 100.0
# sink haha 245 1
# id: 245, src: 1, time: 367.5, size: 100.0
# sink haha 245 2
# id: 245, src: 2, time: 367.5, size: 100.0
# sink haha 243 3
# id: 243, src: 3, time: 364.5, size: 100.0
# sink haha 246 2
# id: 246, src: 2, time: 369.0, size: 100.0
# sink haha 250 2
# id: 250, src: 2, time: 375.0, size: 100.0
# sink haha 247 1
# id: 247, src: 1, time: 370.5, size: 100.0
# sink haha 244 3
# id: 244, src: 3, time: 366.0, size: 100.0
# sink haha 242 3
# id: 242, src: 3, time: 363.0, size: 100.0
# sink haha 248 2
# id: 248, src: 2, time: 372.0, size: 100.0
# sink haha 245 3
# id: 245, src: 3, time: 367.5, size: 100.0
# sink haha 246 1
# id: 246, src: 1, time: 369.0, size: 100.0
# sink haha 249 2
# id: 249, src: 2, time: 373.5, size: 100.0
# sink haha 250 1
# id: 250, src: 1, time: 375.0, size: 100.0
# sink haha 246 3
# id: 246, src: 3, time: 369.0, size: 100.0
# sink haha 251 1
# id: 251, src: 1, time: 376.5, size: 100.0
# sink haha 247 3
# id: 247, src: 3, time: 370.5, size: 100.0
# sink haha 248 1
# id: 248, src: 1, time: 372.0, size: 100.0
# sink haha 248 3
# id: 248, src: 3, time: 372.0, size: 100.0
# sink haha 252 1
# id: 252, src: 1, time: 378.0, size: 100.0
# sink haha 249 1
# id: 249, src: 1, time: 373.5, size: 100.0
# sink haha 251 2
# id: 251, src: 2, time: 376.5, size: 100.0
# sink haha 250 3
# id: 250, src: 3, time: 375.0, size: 100.0
# sink haha 252 2
# id: 252, src: 2, time: 378.0, size: 100.0
# sink haha 249 3
# id: 249, src: 3, time: 373.5, size: 100.0
# sink haha 251 3
# id: 251, src: 3, time: 376.5, size: 100.0
# sink haha 252 3
# id: 252, src: 3, time: 378.0, size: 100.0
# sink haha 253 2
# id: 253, src: 2, time: 379.5, size: 100.0
# sink haha 253 1
# id: 253, src: 1, time: 379.5, size: 100.0
# sink haha 253 3
# id: 253, src: 3, time: 379.5, size: 100.0
# sink haha 254 2
# id: 254, src: 2, time: 381.0, size: 100.0
# sink haha 255 1
# id: 255, src: 1, time: 382.5, size: 100.0
# sink haha 254 1
# id: 254, src: 1, time: 381.0, size: 100.0
# sink haha 254 3
# id: 254, src: 3, time: 381.0, size: 100.0
# sink haha 255 2
# id: 255, src: 2, time: 382.5, size: 100.0
# sink haha 257 1
# id: 257, src: 1, time: 385.5, size: 100.0
# sink haha 255 3
# id: 255, src: 3, time: 382.5, size: 100.0
# sink haha 256 2
# id: 256, src: 2, time: 384.0, size: 100.0
# sink haha 256 3
# id: 256, src: 3, time: 384.0, size: 100.0
# sink haha 256 1
# id: 256, src: 1, time: 384.0, size: 100.0
# sink haha 258 3
# id: 258, src: 3, time: 387.0, size: 100.0
# sink haha 257 3
# id: 257, src: 3, time: 385.5, size: 100.0
# sink haha 259 1
# id: 259, src: 1, time: 388.5, size: 100.0
# sink haha 257 2
# id: 257, src: 2, time: 385.5, size: 100.0
# sink haha 259 2
# id: 259, src: 2, time: 388.5, size: 100.0
# sink haha 258 1
# id: 258, src: 1, time: 387.0, size: 100.0
# sink haha 260 1
# id: 260, src: 1, time: 390.0, size: 100.0
# sink haha 258 2
# id: 258, src: 2, time: 387.0, size: 100.0
# sink haha 259 3
# id: 259, src: 3, time: 388.5, size: 100.0
# sink haha 261 1
# id: 261, src: 1, time: 391.5, size: 100.0
# sink haha 260 3
# id: 260, src: 3, time: 390.0, size: 100.0
# sink haha 260 2
# id: 260, src: 2, time: 390.0, size: 100.0
# sink haha 262 1
# id: 262, src: 1, time: 393.0, size: 100.0
# sink haha 263 1
# id: 263, src: 1, time: 394.5, size: 100.0
# sink haha 261 3
# id: 261, src: 3, time: 391.5, size: 100.0
# sink haha 261 2
# id: 261, src: 2, time: 391.5, size: 100.0
# sink haha 262 2
# id: 262, src: 2, time: 393.0, size: 100.0
# sink haha 264 3
# id: 264, src: 3, time: 396.0, size: 100.0
# sink haha 265 1
# id: 265, src: 1, time: 397.5, size: 100.0
# sink haha 262 3
# id: 262, src: 3, time: 393.0, size: 100.0
# sink haha 265 3
# id: 265, src: 3, time: 397.5, size: 100.0
# sink haha 263 3
# id: 263, src: 3, time: 394.5, size: 100.0
# sink haha 263 2
# id: 263, src: 2, time: 394.5, size: 100.0
# sink haha 266 3
# id: 266, src: 3, time: 399.0, size: 100.0
# sink haha 266 1
# id: 266, src: 1, time: 399.0, size: 100.0
# sink haha 264 1
# id: 264, src: 1, time: 396.0, size: 100.0
# sink haha 264 2
# id: 264, src: 2, time: 396.0, size: 100.0
# sink haha 267 1
# id: 267, src: 1, time: 400.5, size: 100.0
# sink haha 267 3
# id: 267, src: 3, time: 400.5, size: 100.0
# sink haha 265 2
# id: 265, src: 2, time: 397.5, size: 100.0
# sink haha 266 2
# id: 266, src: 2, time: 399.0, size: 100.0
# sink haha 267 2
# id: 267, src: 2, time: 400.5, size: 100.0
# sink haha 268 1
# id: 268, src: 1, time: 402.0, size: 100.0
# sink haha 268 3
# id: 268, src: 3, time: 402.0, size: 100.0
# sink haha 268 2
# id: 268, src: 2, time: 402.0, size: 100.0
# sink haha 269 1
# id: 269, src: 1, time: 403.5, size: 100.0
# sink haha 270 3
# id: 270, src: 3, time: 405.0, size: 100.0
# sink haha 269 3
# id: 269, src: 3, time: 403.5, size: 100.0
# sink haha 269 2
# id: 269, src: 2, time: 403.5, size: 100.0
# sink haha 270 1
# id: 270, src: 1, time: 405.0, size: 100.0
# sink haha 271 3
# id: 271, src: 3, time: 406.5, size: 100.0
# sink haha 271 1
# id: 271, src: 1, time: 406.5, size: 100.0
# sink haha 270 2
# id: 270, src: 2, time: 405.0, size: 100.0
# sink haha 272 3
# id: 272, src: 3, time: 408.0, size: 100.0
# sink haha 273 3
# id: 273, src: 3, time: 409.5, size: 100.0
# sink haha 272 1
# id: 272, src: 1, time: 408.0, size: 100.0
# sink haha 273 2
# id: 273, src: 2, time: 409.5, size: 100.0
# sink haha 273 1
# id: 273, src: 1, time: 409.5, size: 100.0
# sink haha 271 2
# id: 271, src: 2, time: 406.5, size: 100.0
# sink haha 274 2
# id: 274, src: 2, time: 411.0, size: 100.0
# sink haha 274 1
# id: 274, src: 1, time: 411.0, size: 100.0
# sink haha 272 2
# id: 272, src: 2, time: 408.0, size: 100.0
# sink haha 274 3
# id: 274, src: 3, time: 411.0, size: 100.0
# sink haha 275 2
# id: 275, src: 2, time: 412.5, size: 100.0
# sink haha 275 1
# id: 275, src: 1, time: 412.5, size: 100.0
# sink haha 275 3
# id: 275, src: 3, time: 412.5, size: 100.0
# sink haha 276 2
# id: 276, src: 2, time: 414.0, size: 100.0
# sink haha 276 3
# id: 276, src: 3, time: 414.0, size: 100.0
# sink haha 276 1
# id: 276, src: 1, time: 414.0, size: 100.0
# sink haha 277 1
# id: 277, src: 1, time: 415.5, size: 100.0
# sink haha 277 3
# id: 277, src: 3, time: 415.5, size: 100.0
# sink haha 277 2
# id: 277, src: 2, time: 415.5, size: 100.0
# sink haha 278 2
# id: 278, src: 2, time: 417.0, size: 100.0
# sink haha 279 1
# id: 279, src: 1, time: 418.5, size: 100.0
# sink haha 278 3
# id: 278, src: 3, time: 417.0, size: 100.0
# sink haha 279 2
# id: 279, src: 2, time: 418.5, size: 100.0
# sink haha 281 3
# id: 281, src: 3, time: 421.5, size: 100.0
# sink haha 279 3
# id: 279, src: 3, time: 418.5, size: 100.0
# sink haha 282 3
# id: 282, src: 3, time: 423.0, size: 100.0
# sink haha 278 1
# id: 278, src: 1, time: 417.0, size: 100.0
# sink haha 280 3
# id: 280, src: 3, time: 420.0, size: 100.0
# sink haha 281 2
# id: 281, src: 2, time: 421.5, size: 100.0
# sink haha 282 1
# id: 282, src: 1, time: 423.0, size: 100.0
# sink haha 280 1
# ...
# id: 569, src: 2, time: 853.5, size: 100.0
# sink haha 577 2
# id: 577, src: 2, time: 865.5, size: 100.0
# sink haha 572 1
# id: 572, src: 1, time: 858.0, size: 100.0
# sink haha 573 1
# id: 573, src: 1, time: 859.5, size: 100.0
# sink haha 578 2
# id: 578, src: 2, time: 867.0, size: 100.0
# sink haha 571 2
# id: 571, src: 2, time: 856.5, size: 100.0
# sink haha 578 3
# id: 578, src: 3, time: 867.0, size: 100.0
# sink haha 572 2
# id: 572, src: 2, time: 858.0, size: 100.0
# sink haha 574 3
# id: 574, src: 3, time: 861.0, size: 100.0
# sink haha 579 3
# id: 579, src: 3, time: 868.5, size: 100.0
# sink haha 573 2
# id: 573, src: 2, time: 859.5, size: 100.0
# sink haha 580 3
# id: 580, src: 3, time: 870.0, size: 100.0
# sink haha 574 2
# id: 574, src: 2, time: 861.0, size: 100.0
# sink haha 582 3
# id: 582, src: 3, time: 873.0, size: 100.0
# sink haha 580 2
# id: 580, src: 2, time: 870.0, size: 100.0
# sink haha 575 2
# id: 575, src: 2, time: 862.5, size: 100.0
# sink haha 574 1
# id: 574, src: 1, time: 861.0, size: 100.0
# sink haha 577 3
# id: 577, src: 3, time: 865.5, size: 100.0
# sink haha 578 1
# id: 578, src: 1, time: 867.0, size: 100.0
# sink haha 584 3
# id: 584, src: 3, time: 876.0, size: 100.0
# sink haha 576 2
# id: 576, src: 2, time: 864.0, size: 100.0
# sink haha 585 3
# id: 585, src: 3, time: 877.5, size: 100.0
# sink haha 575 1
# id: 575, src: 1, time: 862.5, size: 100.0
# sink haha 581 3
# id: 581, src: 3, time: 871.5, size: 100.0
# sink haha 586 3
# id: 586, src: 3, time: 879.0, size: 100.0
# sink haha 576 1
# id: 576, src: 1, time: 864.0, size: 100.0
# sink haha 579 2
# id: 579, src: 2, time: 868.5, size: 100.0
# sink haha 587 3
# id: 587, src: 3, time: 880.5, size: 100.0
# sink haha 577 1
# id: 577, src: 1, time: 865.5, size: 100.0
# sink haha 583 3
# id: 583, src: 3, time: 874.5, size: 100.0
# sink haha 586 2
# id: 586, src: 2, time: 879.0, size: 100.0
# sink haha 581 2
# id: 581, src: 2, time: 871.5, size: 100.0
# sink haha 589 3
# id: 589, src: 3, time: 883.5, size: 100.0
# sink haha 582 1
# id: 582, src: 1, time: 873.0, size: 100.0
# sink haha 579 1
# id: 579, src: 1, time: 868.5, size: 100.0
# sink haha 582 2
# id: 582, src: 2, time: 873.0, size: 100.0
# sink haha 583 1
# id: 583, src: 1, time: 874.5, size: 100.0
# sink haha 580 1
# id: 580, src: 1, time: 870.0, size: 100.0
# sink haha 583 2
# id: 583, src: 2, time: 874.5, size: 100.0
# sink haha 590 2
# id: 590, src: 2, time: 885.0, size: 100.0
# sink haha 592 3
# id: 592, src: 3, time: 888.0, size: 100.0
# sink haha 581 1
# id: 581, src: 1, time: 871.5, size: 100.0
# sink haha 584 2
# id: 584, src: 2, time: 876.0, size: 100.0
# sink haha 591 2
# id: 591, src: 2, time: 886.5, size: 100.0
# sink haha 585 1
# id: 585, src: 1, time: 877.5, size: 100.0
# sink haha 588 3
# id: 588, src: 3, time: 882.0, size: 100.0
# sink haha 585 2
# id: 585, src: 2, time: 877.5, size: 100.0
# sink haha 586 1
# id: 586, src: 1, time: 879.0, size: 100.0
# sink haha 592 2
# id: 592, src: 2, time: 888.0, size: 100.0
# sink haha 587 2
# id: 587, src: 2, time: 880.5, size: 100.0
# sink haha 587 1
# id: 587, src: 1, time: 880.5, size: 100.0
# sink haha 596 3
# id: 596, src: 3, time: 894.0, size: 100.0
# sink haha 588 2
# id: 588, src: 2, time: 882.0, size: 100.0
# sink haha 590 3
# id: 590, src: 3, time: 885.0, size: 100.0
# sink haha 584 1
# id: 584, src: 1, time: 876.0, size: 100.0
# sink haha 597 3
# id: 597, src: 3, time: 895.5, size: 100.0
# sink haha 591 3
# id: 591, src: 3, time: 886.5, size: 100.0
# sink haha 589 2
# id: 589, src: 2, time: 883.5, size: 100.0
# sink haha 598 3
# id: 598, src: 3, time: 897.0, size: 100.0
# sink haha 599 3
# id: 599, src: 3, time: 898.5, size: 100.0
# sink haha 593 3
# id: 593, src: 3, time: 889.5, size: 100.0
# sink haha 588 1
# id: 588, src: 1, time: 882.0, size: 100.0
# sink haha 590 1
# id: 590, src: 1, time: 885.0, size: 100.0
# sink haha 593 2
# id: 593, src: 2, time: 889.5, size: 100.0
# sink haha 594 3
# id: 594, src: 3, time: 891.0, size: 100.0
# sink haha 589 1
# id: 589, src: 1, time: 883.5, size: 100.0
# sink haha 600 3
# id: 600, src: 3, time: 900.0, size: 100.0
# sink haha 594 2
# id: 594, src: 2, time: 891.0, size: 100.0
# sink haha 601 3
# id: 601, src: 3, time: 901.5, size: 100.0
# sink haha 592 1
# id: 592, src: 1, time: 888.0, size: 100.0
# sink haha 595 3
# id: 595, src: 3, time: 892.5, size: 100.0
# sink haha 602 3
# id: 602, src: 3, time: 903.0, size: 100.0
# sink haha 595 2
# id: 595, src: 2, time: 892.5, size: 100.0
# sink haha 591 1
# id: 591, src: 1, time: 886.5, size: 100.0
# sink haha 593 1
# id: 593, src: 1, time: 889.5, size: 100.0
# sink haha 596 2
# id: 596, src: 2, time: 894.0, size: 100.0
# sink haha 603 3
# id: 603, src: 3, time: 904.5, size: 100.0
# sink haha 604 3
# id: 604, src: 3, time: 906.0, size: 100.0
# sink haha 597 2
# id: 597, src: 2, time: 895.5, size: 100.0
# sink haha 605 3
# id: 605, src: 3, time: 907.5, size: 100.0
# sink haha 594 1
# id: 594, src: 1, time: 891.0, size: 100.0
# sink haha 606 3
# id: 606, src: 3, time: 909.0, size: 100.0
# sink haha 595 1
# id: 595, src: 1, time: 892.5, size: 100.0
# sink haha 604 2
# id: 604, src: 2, time: 906.0, size: 100.0
# sink haha 598 2
# id: 598, src: 2, time: 897.0, size: 100.0
# sink haha 599 2
# id: 599, src: 2, time: 898.5, size: 100.0
# sink haha 596 1
# id: 596, src: 1, time: 894.0, size: 100.0
# sink haha 607 3
# id: 607, src: 3, time: 910.5, size: 100.0
# sink haha 605 2
# id: 605, src: 2, time: 907.5, size: 100.0
# sink haha 600 2
# id: 600, src: 2, time: 900.0, size: 100.0
# sink haha 597 1
# id: 597, src: 1, time: 895.5, size: 100.0
# sink haha 609 3
# id: 609, src: 3, time: 913.5, size: 100.0
# sink haha 601 2
# id: 601, src: 2, time: 901.5, size: 100.0
# sink haha 600 1
# id: 600, src: 1, time: 900.0, size: 100.0
# sink haha 598 1
# id: 598, src: 1, time: 897.0, size: 100.0
# sink haha 610 3
# id: 610, src: 3, time: 915.0, size: 100.0
# sink haha 602 2
# id: 602, src: 2, time: 903.0, size: 100.0
# sink haha 611 3
# id: 611, src: 3, time: 916.5, size: 100.0
# sink haha 599 1
# id: 599, src: 1, time: 898.5, size: 100.0
# sink haha 602 1
# id: 602, src: 1, time: 903.0, size: 100.0
# sink haha 603 2
# id: 603, src: 2, time: 904.5, size: 100.0
# sink haha 608 3
# id: 608, src: 3, time: 912.0, size: 100.0
# sink haha 601 1
# id: 601, src: 1, time: 901.5, size: 100.0
# sink haha 613 3
# id: 613, src: 3, time: 919.5, size: 100.0
# sink haha 603 1
# id: 603, src: 1, time: 904.5, size: 100.0
# sink haha 610 2
# id: 610, src: 2, time: 915.0, size: 100.0
# sink haha 606 2
# id: 606, src: 2, time: 909.0, size: 100.0
# sink haha 612 3
# id: 612, src: 3, time: 918.0, size: 100.0
# sink haha 605 1
# id: 605, src: 1, time: 907.5, size: 100.0
# sink haha 614 3
# id: 614, src: 3, time: 921.0, size: 100.0
# sink haha 604 1
# id: 604, src: 1, time: 906.0, size: 100.0
# sink haha 607 2
# id: 607, src: 2, time: 910.5, size: 100.0
# sink haha 606 1
# id: 606, src: 1, time: 909.0, size: 100.0
# sink haha 612 2
# id: 612, src: 2, time: 918.0, size: 100.0
# sink haha 608 2
# id: 608, src: 2, time: 912.0, size: 100.0
# sink haha 615 3
# id: 615, src: 3, time: 922.5, size: 100.0
# sink haha 609 2
# id: 609, src: 2, time: 913.5, size: 100.0
# sink haha 617 3
# id: 617, src: 3, time: 925.5, size: 100.0
# sink haha 607 1
# id: 607, src: 1, time: 910.5, size: 100.0
# sink haha 609 1
# id: 609, src: 1, time: 913.5, size: 100.0
# sink haha 615 2
# id: 615, src: 2, time: 922.5, size: 100.0
# sink haha 616 3
# id: 616, src: 3, time: 924.0, size: 100.0
# sink haha 610 1
# id: 610, src: 1, time: 915.0, size: 100.0
# sink haha 618 3
# id: 618, src: 3, time: 927.0, size: 100.0
# sink haha 611 2
# id: 611, src: 2, time: 916.5, size: 100.0
# sink haha 608 1
# id: 608, src: 1, time: 912.0, size: 100.0
# sink haha 616 2
# id: 616, src: 2, time: 924.0, size: 100.0
# sink haha 619 3
# id: 619, src: 3, time: 928.5, size: 100.0
# sink haha 613 2
# id: 613, src: 2, time: 919.5, size: 100.0
# sink haha 612 1
# id: 612, src: 1, time: 918.0, size: 100.0
# sink haha 620 3
# id: 620, src: 3, time: 930.0, size: 100.0
# sink haha 614 2
# id: 614, src: 2, time: 921.0, size: 100.0
# sink haha 613 1
# id: 613, src: 1, time: 919.5, size: 100.0
# sink haha 611 1
# id: 611, src: 1, time: 916.5, size: 100.0
# sink haha 621 3
# id: 621, src: 3, time: 931.5, size: 100.0
# sink haha 614 1
# id: 614, src: 1, time: 921.0, size: 100.0
# sink haha 615 1
# id: 615, src: 1, time: 922.5, size: 100.0
# sink haha 617 2
# id: 617, src: 2, time: 925.5, size: 100.0
# sink haha 623 3
# id: 623, src: 3, time: 934.5, size: 100.0
# sink haha 622 3
# id: 622, src: 3, time: 933.0, size: 100.0
# sink haha 618 2
# id: 618, src: 2, time: 927.0, size: 100.0
# sink haha 619 2
# id: 619, src: 2, time: 928.5, size: 100.0
# sink haha 622 2
# id: 622, src: 2, time: 933.0, size: 100.0
# sink haha 625 3
# id: 625, src: 3, time: 937.5, size: 100.0
# sink haha 616 1
# id: 616, src: 1, time: 924.0, size: 100.0
# sink haha 624 3
# id: 624, src: 3, time: 936.0, size: 100.0
# sink haha 620 2
# id: 620, src: 2, time: 930.0, size: 100.0
# sink haha 618 1
# id: 618, src: 1, time: 927.0, size: 100.0
# sink haha 617 1
# id: 617, src: 1, time: 925.5, size: 100.0
# sink haha 626 3
# id: 626, src: 3, time: 939.0, size: 100.0
# sink haha 621 2
# id: 621, src: 2, time: 931.5, size: 100.0
# sink haha 628 3
# id: 628, src: 3, time: 942.0, size: 100.0
# sink haha 620 1
# id: 620, src: 1, time: 930.0, size: 100.0
# sink haha 619 1
# id: 619, src: 1, time: 928.5, size: 100.0
# sink haha 621 1
# id: 621, src: 1, time: 931.5, size: 100.0
# sink haha 624 2
# id: 624, src: 2, time: 936.0, size: 100.0
# sink haha 627 3
# id: 627, src: 3, time: 940.5, size: 100.0
# sink haha 629 3
# id: 629, src: 3, time: 943.5, size: 100.0
# sink haha 623 2
# id: 623, src: 2, time: 934.5, size: 100.0
# sink haha 625 2
# id: 625, src: 2, time: 937.5, size: 100.0
# sink haha 623 1
# id: 623, src: 1, time: 934.5, size: 100.0
# sink haha 622 1
# id: 622, src: 1, time: 933.0, size: 100.0
# sink haha 630 3
# id: 630, src: 3, time: 945.0, size: 100.0
# sink haha 632 3
# id: 632, src: 3, time: 948.0, size: 100.0
# sink haha 624 1
# id: 624, src: 1, time: 936.0, size: 100.0
# sink haha 626 2
# id: 626, src: 2, time: 939.0, size: 100.0
# sink haha 631 3
# id: 631, src: 3, time: 946.5, size: 100.0
# sink haha 627 2
# id: 627, src: 2, time: 940.5, size: 100.0
# sink haha 633 3
# id: 633, src: 3, time: 949.5, size: 100.0
# sink haha 634 3
# id: 634, src: 3, time: 951.0, size: 100.0
# sink haha 625 1
# id: 625, src: 1, time: 937.5, size: 100.0
# sink haha 626 1
# id: 626, src: 1, time: 939.0, size: 100.0
# sink haha 628 2
# id: 628, src: 2, time: 942.0, size: 100.0
# sink haha 627 1
# id: 627, src: 1, time: 940.5, size: 100.0
# sink haha 629 2
# id: 629, src: 2, time: 943.5, size: 100.0
# sink haha 628 1
# id: 628, src: 1, time: 942.0, size: 100.0
# sink haha 637 3
# id: 637, src: 3, time: 955.5, size: 100.0
# sink haha 630 2
# id: 630, src: 2, time: 945.0, size: 100.0
# sink haha 629 1
# id: 629, src: 1, time: 943.5, size: 100.0
# sink haha 638 3
# id: 638, src: 3, time: 957.0, size: 100.0
# sink haha 635 3
# id: 635, src: 3, time: 952.5, size: 100.0
# sink haha 631 2
# id: 631, src: 2, time: 946.5, size: 100.0
# sink haha 633 2
# id: 633, src: 2, time: 949.5, size: 100.0
# sink haha 630 1
# id: 630, src: 1, time: 945.0, size: 100.0
# sink haha 631 1
# id: 631, src: 1, time: 946.5, size: 100.0
# sink haha 636 3
# id: 636, src: 3, time: 954.0, size: 100.0
# sink haha 632 2
# id: 632, src: 2, time: 948.0, size: 100.0
# sink haha 632 1
# id: 632, src: 1, time: 948.0, size: 100.0
# sink haha 639 3
# id: 639, src: 3, time: 958.5, size: 100.0
# sink haha 633 1
# id: 633, src: 1, time: 949.5, size: 100.0
# sink haha 640 3
# id: 640, src: 3, time: 960.0, size: 100.0
# sink haha 634 1
# id: 634, src: 1, time: 951.0, size: 100.0
# sink haha 634 2
# id: 634, src: 2, time: 951.0, size: 100.0
# sink haha 637 2
# id: 637, src: 2, time: 955.5, size: 100.0
# sink haha 635 2
# id: 635, src: 2, time: 952.5, size: 100.0
# sink haha 641 3
# id: 641, src: 3, time: 961.5, size: 100.0
# sink haha 636 2
# id: 636, src: 2, time: 954.0, size: 100.0
# sink haha 635 1
# id: 635, src: 1, time: 952.5, size: 100.0
# sink haha 639 2
# id: 639, src: 2, time: 958.5, size: 100.0
# sink haha 638 2
# id: 638, src: 2, time: 957.0, size: 100.0
# sink haha 643 3
# id: 643, src: 3, time: 964.5, size: 100.0
# sink haha 636 1
# id: 636, src: 1, time: 954.0, size: 100.0
# sink haha 640 2
# id: 640, src: 2, time: 960.0, size: 100.0
# sink haha 637 1
# id: 637, src: 1, time: 955.5, size: 100.0
# sink haha 642 3
# id: 642, src: 3, time: 963.0, size: 100.0
# sink waits: [3.0999999999999996, 3.1999999999999993, 3.8999999999999995, 4.099999999999999, 5.6, 6.4, 5.0, 7.3000000000000025, 7.400000000000002, 7.5000000000000036, 8.200000000000005, 7.500000000000005, 9.100000000000005, 9.200000000000006, 10.700000000000006, 11.600000000000009, 12.50000000000001, 13.300000000000011, 12.50000000000001, 12.600000000000012, 12.600000000000012, 14.200000000000014, 13.400000000000013, 15.100000000000016, 14.300000000000015, 16.700000000000017, 16.80000000000002, 16.80000000000002, 17.600000000000016, 18.500000000000014, 17.10000000000001, 19.300000000000004, 18.700000000000003, 21.699999999999996, 22.599999999999994, 20.39999999999999, 23.399999999999984, 21.999999999999986, 22.899999999999977, 25.099999999999973, 25.29999999999997, 25.399999999999963, 26.899999999999963, 24.69999999999996, 26.899999999999956, 26.199999999999953, 27.799999999999955, 27.799999999999947, 26.39999999999995, 27.89999999999994, 28.79999999999994, 27.999999999999936, 28.899999999999928, 31.299999999999926, 32.09999999999992, 31.29999999999992, 32.999999999999915, 32.99999999999991, 33.799999999999905, 35.599999999999895, 36.2999999999999, 37.89999999999989, 37.19999999999989, 38.79999999999988, 37.29999999999988, 38.89999999999988, 38.199999999999875, 37.39999999999988, 41.29999999999987, 40.49999999999987, 39.899999999999864, 39.899999999999864, 42.299999999999855, 41.49999999999986, 40.799999999999855, 42.39999999999985, 43.29999999999984, 43.29999999999984, 44.899999999999835, 44.99999999999983, 44.29999999999983, 48.099999999999824, 45.89999999999982, 47.39999999999982, 45.999999999999815, 47.59999999999981, 49.199999999999804, 50.699999999999804, 49.2999999999998, 50.89999999999979, 51.599999999999795, 51.799999999999784, 54.09999999999978, 54.199999999999775, 54.29999999999977, 54.99999999999977, 53.59999999999977, 55.09999999999977, 55.99999999999976, 57.59999999999975, 53.09999999999975, 56.89999999999975, 56.999999999999744, 57.69999999999975, 59.999999999999744, 60.899999999999736, 59.49999999999973, 61.099999999999724, 59.599999999999724, 61.19999999999972, 60.39999999999972, 65.09999999999971, 62.09999999999971, 62.09999999999971, 62.9999999999997, 63.7999999999997, 63.89999999999969, 66.0999999999997, 67.69999999999969, 65.59999999999968, 66.29999999999968, 65.59999999999968, 67.19999999999968, 70.2999999999997, 66.49999999999972, 68.09999999999971, 70.39999999999975, 68.99999999999977, 71.39999999999978, 72.8999999999998, 71.4999999999998, 70.79999999999984, 72.39999999999984, 73.19999999999985, 71.69999999999987, 77.09999999999988, 75.6999999999999, 73.39999999999992, 79.49999999999994, 76.59999999999994, 75.89999999999998, 81.19999999999999, 79.9, 82.10000000000002, 78.40000000000003, 83.90000000000006, 82.40000000000006, 83.10000000000008, 80.20000000000007, 81.00000000000009, 83.2000000000001, 82.60000000000014, 85.70000000000013, 84.20000000000016, 85.80000000000015, 85.9000000000002, 88.30000000000021, 87.50000000000023, 87.60000000000022, 87.70000000000024, 88.40000000000026, 90.10000000000028, 90.1000000000003, 90.90000000000032, 91.80000000000032, 91.80000000000035, 93.40000000000038, 94.30000000000038, 92.10000000000039, 94.4000000000004, 95.90000000000043, 96.00000000000043, 95.30000000000044, 96.80000000000047, 97.7000000000005, 94.8000000000005, 98.50000000000051, 98.6000000000005, 98.60000000000053, 96.50000000000054, 100.20000000000056, 101.90000000000057, 102.70000000000061, 102.80000000000061, 102.90000000000066, 104.50000000000065, 102.30000000000067, 106.8000000000007, 104.6000000000007, 106.2000000000007, 103.30000000000072, 109.30000000000075, 104.90000000000074, 107.90000000000077, 108.00000000000077, 105.80000000000078, 111.80000000000081, 109.80000000000084, 109.10000000000085, 114.30000000000086, 112.10000000000088, 110.00000000000088, 111.50000000000088, 115.2000000000009, 110.90000000000092, 112.40000000000092, 115.40000000000094, 113.30000000000095, 114.10000000000096, 117.100 ...
# 1 received: 1920, dropped 0, sent 1333
# 2 received: 1920, dropped 0, sent 1333
# 3 received: 1920, dropped 0, sent 1333

# %%
from numpy.random import choice

# %%
prob=[0.5,0.5,0]

# %%
draw = choice([3,4,5], 
              p=prob)

# %%
draw
# Out:
# 4
