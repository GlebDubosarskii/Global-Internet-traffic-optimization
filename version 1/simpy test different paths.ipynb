# %%
import simpy
from numpy.random import choice

# %%
n=5 #Prime router number
N=3 #regular router number
m=3 #shortest path number

# %%
class Packet(object):
    """ A very simple class that represents a packet.
        This packet will run through a queue at a switch output port.
        We use a float to represent the size of the packet in bytes so that
        we can compare to ideal M/M/1 queues.

        Parameters
        ----------
        time : float
            the time the packet arrives at the output queue.
        size : float
            the size of the packet in bytes
        id : int
            an identifier for the packet
        src, dst : int
            identifiers for source and destination

    """
    def __init__(self, packet_id, path, cur_path_ind, time, size, src, dst):
        
        self.packet_id=packet_id
        self.path=path
        self.cur_path_ind=cur_path_ind
        
        
        self.time = time
        self.size = size
        self.src = src
        self.dst = dst


    def __repr__(self):
        return "id: {}, src: {}, time: {}, size: {}".\
            format(self.packet_id, self.src, self.time, self.size)

# %% [markdown]
# '''path, cur_path_ind, '''

# %%
class PacketGenerator(object):
    """ Generates packets with given inter-arrival time distribution.
        Set the "out" member variable to the entity to receive the packet.

        Parameters
        ----------
        env : simpy.Environment
            the simulation environment
        adist : function
            a no parameter function that returns the successive inter-arrival times of the packets
        sdist : function
            a no parameter function that returns the successive sizes of the packets
        initial_delay : number
            Starts generation after an initial delay. Default = 0
        finish : number
            Stops generation at the finish time. Default is infinite


    """
    def __init__(self, env, gen_prob, generator_id,  adist, sdist, initial_delay=0, finish=float("inf")):
        
        self.gen_prob=gen_prob
        self.generator_id = generator_id
        self.env = env
        self.adist = adist
        self.sdist = sdist
        self.initial_delay = initial_delay
        self.finish = finish
        self.out = None
        self.packets_sent = 0
        self.action = env.process(self.run())  # starts the run() method as a SimPy process


    def run(self):
        """The generator function used in simulations.
        """
        
        yield self.env.timeout(self.initial_delay)
        while self.env.now < self.finish:
            # wait for next transmission
            yield self.env.timeout(self.adist())
            
            destination = choice(range(1,N+1), p=self.gen_prob)
            print('destination',destination)
            #print('id',self.generator_id)
            opt_path=path[self.generator_id][destination]
            
            print('opt_path',opt_path)
            
            self.packets_sent += 1
            
            
            pkt = Packet(packet_id=self.packets_sent, 
                         path=opt_path, 
                         cur_path_ind=0, 
                         time=self.env.now, 
                         size=self.sdist(), 
                         src=self.generator_id, 
                         dst=destination)
            
            #if next_node==destination:
            #    sink[destination].put(p)
            #else:
            #    switch[destination].put(p)
            
            self.out.put(pkt)

# %%
class PacketSink(object):
    """ Receives packets and collects delay information into the
        waits list. You can then use this list to look at delay statistics.

        Parameters
        ----------
        env : simpy.Environment
            the simulation environment
        debug : boolean
            if true then the contents of each packet will be printed as it is received.
        rec_arrivals : boolean
            if true then arrivals will be recorded
        absolute_arrivals : boolean
            if true absolute arrival times will be recorded, otherwise the time between consecutive arrivals
            is recorded.
        rec_waits : boolean
            if true waiting time experienced by each packet is recorded
        selector: a function that takes a packet and returns a boolean
            used for selective statistics. Default none.

    """
    def __init__(self, env, rec_arrivals=False, absolute_arrivals=False, rec_waits=True, debug=False, selector=None):
        self.store = simpy.Store(env)
        self.env = env
        self.rec_waits = rec_waits
        self.rec_arrivals = rec_arrivals
        self.absolute_arrivals = absolute_arrivals
        self.waits = []
        self.arrivals = []
        self.debug = debug
        self.packets_rec = 0
        self.bytes_rec = 0
        self.selector = selector
        self.last_arrival = 0.0

    def put(self, pkt):
        #print('packet_id',pkt.id)
        print('sink',pkt)
        
        if not self.selector or self.selector(pkt):
            now = self.env.now
            if self.rec_waits:
                self.waits.append(self.env.now - pkt.time)
            if self.rec_arrivals:
                if self.absolute_arrivals:
                    self.arrivals.append(now)
                else:
                    self.arrivals.append(now - self.last_arrival)
                self.last_arrival = now
            self.packets_rec += 1
            self.bytes_rec += pkt.size
            if self.debug:
                print(pkt)

# %%
class SwitchPort(object):
    """ Models a switch output port with a given rate and buffer size limit in bytes.
        Set the "out" member variable to the entity to receive the packet.

        Parameters
        ----------
        env : simpy.Environment
            the simulation environment
        rate : float
            the bit rate of the port
        qlimit : integer (or None)
            a buffer size limit in bytes or packets for the queue (including items
            in service).
        limit_bytes : If true, the queue limit will be based on bytes if false the
            queue limit will be based on packets.

    """
    def __init__(self, env, router_id, rate, qlimit=None, limit_bytes=True, debug=False):
        self.id=router_id
        self.store = simpy.Store(env)
        self.rate = rate
        self.env = env
        self.out = None
        self.packets_rec = 0
        self.packets_drop = 0
        self.qlimit = qlimit
        self.limit_bytes = limit_bytes
        self.byte_size = 0  # Current size of the queue in bytes
        self.debug = debug
        self.busy = 0  # Used to track if a packet is currently being sent
        self.action = env.process(self.run())  # starts the run() method as a SimPy process

    def run(self):
        while True:
            msg = (yield self.store.get())
            print('self.store',self.store)
            self.busy = 1
            self.byte_size -= msg.size
            yield self.env.timeout(msg.size*8/self.rate)#(msg.size/self.rate)
            #self.out.put(msg)
            
                
            path=msg.path
            cur_path_ind=msg.cur_path_ind
            destination=msg.dst
                
            #print('path',path)
            #print('cur_path_ind',cur_path_ind)
            #print('destination',destination)
            #print('path[cur_path_ind]',path[cur_path_ind])
            
            #self.packet_id=packet_id
            #self.path=path
            #self.cur_path_ind=cur_path_ind
            print('msg packet_id src ',msg.packet_id, msg.src)
                
            if path[cur_path_ind]==destination:
                print('send to sink' + str(destination))
                sink[destination].put(msg)
            else:
                next_node=path[cur_path_ind+1]
                print('send to switch' + str(next_node))
                msg.cur_path_ind=cur_path_ind+1
                #print('msg.cur_path_ind_after',msg.cur_path_ind)
                
                '''
                pck = Packet(packet_id=msg.packet_id, 
                         path=msg.path, 
                         cur_path_ind=msg.cur_path_ind+1, 
                         time=msg.time, 
                         size=msg.size, 
                         src=msg.src, 
                         dst=msg.dst)
                
                print('pck.cur_path_ind',pck.cur_path_ind)
                '''
                
                print('msg', msg.packet_id, msg.src)
                switch[next_node].put(msg)
                
            self.busy = 0
            if self.debug:
                print(msg)

    def put(self, pkt):
        self.packets_rec += 1
        tmp_byte_count = self.byte_size + pkt.size

        if self.qlimit is None:
            self.byte_size = tmp_byte_count
            return self.store.put(pkt)
        if self.limit_bytes and tmp_byte_count >= self.qlimit:
            self.packets_drop += 1
            return
        elif not self.limit_bytes and len(self.store.items) >= self.qlimit-1:
            self.packets_drop += 1
        else:
            self.byte_size = tmp_byte_count
            return self.store.put(pkt)

# %%
from random import expovariate
import simpy

def constArrival():  # Constant arrival distribution for generator 1
    return 1.5

def constArrival2():
    return 2.0

def distSize():
    return expovariate(0.01)

# %%
def constArrival():
    return 1.5    # time interval

def constSize():
    return 100.0  # bytes

# %%
path=[0]*4
prob=[0]*4
for i in range(4):
    path[i]=[0]*4


path[1][2]=[1,3,2]
path[2][3]=[2,1,3]
path[3][1]=[3,2,1]
path[2][1]=[2,3,1]
path[3][2]=[3,1,2]
path[1][3]=[1,2,3]

gen_prob=[0]*4
gen_prob[1]=[0,0.5,0.5]
gen_prob[2]=[0.2,0,0.8]
gen_prob[3]=[0.7,0.3,0]

# %%
path
# Out:
# [[0, 0, 0, 0],
#  [0, 0, [1, 3, 2], [1, 2, 3]],
#  [0, [2, 3, 1], 0, [2, 1, 3]],
#  [0, [3, 2, 1], [3, 1, 2], 0]]

# %%
generators=[0]*4
sink=[0]*4
switch=[0]*4

env = simpy.Environment()  # Create the SimPy environment

for i in range(1,4):
    generators[i]=PacketGenerator(env, gen_prob[i], i, constArrival, constSize)
    switch[i]=SwitchPort(env, i, rate=200.0, qlimit=300, debug=True)
    generators[i].out = switch[i]
    
    sink[i]=PacketSink(env, debug=True)

    
env.run(until=2000)

for i in range(1,4):
    print("sink {} waits: {}".format(i, sink[i].waits))
    print("{} received: {}, dropped {}, sent {}".format(i, sink[i].packets_rec,
         switch[i].packets_drop, generators[i].packets_sent))
# Out:
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1 1
# send to switch3
# msg 1 1
# id: 1, src: 1, time: 1.5, size: 100.0
# msg packet_id src  1 2
# send to switch1
# msg 1 2
# id: 1, src: 2, time: 1.5, size: 100.0
# msg packet_id src  1 3
# send to switch2
# msg 1 3
# id: 1, src: 3, time: 1.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  2 1
# send to switch3
# msg 2 1
# id: 2, src: 1, time: 3.0, size: 100.0
# msg packet_id src  2 2
# send to switch1
# msg 2 2
# id: 2, src: 2, time: 3.0, size: 100.0
# msg packet_id src  2 3
# send to switch2
# msg 2 3
# id: 2, src: 3, time: 3.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  3 1
# send to switch2
# msg 3 1
# id: 3, src: 1, time: 4.5, size: 100.0
# msg packet_id src  3 2
# send to switch1
# msg 3 2
# id: 3, src: 2, time: 4.5, size: 100.0
# msg packet_id src  3 3
# send to switch2
# msg 3 3
# id: 3, src: 3, time: 4.5, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  4 1
# send to switch3
# msg 4 1
# id: 4, src: 1, time: 6.0, size: 100.0
# msg packet_id src  4 2
# send to switch1
# msg 4 2
# id: 4, src: 2, time: 6.0, size: 100.0
# msg packet_id src  4 3
# send to switch2
# msg 4 3
# id: 4, src: 3, time: 6.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  7 1
# send to switch2
# msg 7 1
# id: 7, src: 1, time: 10.5, size: 100.0
# msg packet_id src  7 2
# send to switch1
# msg 7 2
# id: 7, src: 2, time: 10.5, size: 100.0
# msg packet_id src  7 3
# send to switch1
# msg 7 3
# id: 7, src: 3, time: 10.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  10 1
# send to switch3
# msg 10 1
# id: 10, src: 1, time: 15.0, size: 100.0
# msg packet_id src  10 2
# send to switch1
# msg 10 2
# id: 10, src: 2, time: 15.0, size: 100.0
# msg packet_id src  10 3
# send to switch2
# msg 10 3
# id: 10, src: 3, time: 15.0, size: 100.0
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  12 1
# send to switch3
# msg 12 1
# id: 12, src: 1, time: 18.0, size: 100.0
# msg packet_id src  12 2
# send to switch1
# msg 12 2
# id: 12, src: 2, time: 18.0, size: 100.0
# msg packet_id src  12 3
# send to switch2
# msg 12 3
# id: 12, src: 3, time: 18.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  15 1
# send to switch3
# msg 15 1
# id: 15, src: 1, time: 22.5, size: 100.0
# msg packet_id src  15 2
# send to switch1
# msg 15 2
# id: 15, src: 2, time: 22.5, size: 100.0
# msg packet_id src  15 3
# send to switch2
# msg 15 3
# id: 15, src: 3, time: 22.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  18 1
# send to switch3
# msg 18 1
# id: 18, src: 1, time: 27.0, size: 100.0
# msg packet_id src  18 2
# send to switch1
# msg 18 2
# id: 18, src: 2, time: 27.0, size: 100.0
# msg packet_id src  18 3
# send to switch2
# msg 18 3
# id: 18, src: 3, time: 27.0, size: 100.0
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  20 1
# send to switch3
# msg 20 1
# id: 20, src: 1, time: 30.0, size: 100.0
# msg packet_id src  20 2
# send to switch1
# msg 20 2
# id: 20, src: 2, time: 30.0, size: 100.0
# msg packet_id src  20 3
# send to switch2
# msg 20 3
# id: 20, src: 3, time: 30.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  23 1
# send to switch2
# msg 23 1
# id: 23, src: 1, time: 34.5, size: 100.0
# msg packet_id src  23 2
# send to switch1
# msg 23 2
# id: 23, src: 2, time: 34.5, size: 100.0
# msg packet_id src  23 3
# send to switch2
# msg 23 3
# id: 23, src: 3, time: 34.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  26 1
# send to switch3
# msg 26 1
# id: 26, src: 1, time: 39.0, size: 100.0
# msg packet_id src  26 2
# send to switch3
# msg 26 2
# id: 26, src: 2, time: 39.0, size: 100.0
# msg packet_id src  26 3
# send to switch2
# msg 26 3
# id: 26, src: 3, time: 39.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  28 1
# send to switch3
# msg 28 1
# id: 28, src: 1, time: 42.0, size: 100.0
# msg packet_id src  28 2
# send to switch3
# msg 28 2
# id: 28, src: 2, time: 42.0, size: 100.0
# msg packet_id src  28 3
# send to switch2
# msg 28 3
# id: 28, src: 3, time: 42.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  31 1
# send to switch3
# msg 31 1
# id: 31, src: 1, time: 46.5, size: 100.0
# msg packet_id src  31 2
# send to switch1
# msg 31 2
# id: 31, src: 2, time: 46.5, size: 100.0
# msg packet_id src  31 3
# send to switch1
# msg 31 3
# id: 31, src: 3, time: 46.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  34 1
# send to switch3
# msg 34 1
# id: 34, src: 1, time: 51.0, size: 100.0
# msg packet_id src  34 2
# send to switch1
# msg 34 2
# id: 34, src: 2, time: 51.0, size: 100.0
# msg packet_id src  34 3
# send to switch1
# msg 34 3
# id: 34, src: 3, time: 51.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  36 1
# send to switch3
# msg 36 1
# id: 36, src: 1, time: 54.0, size: 100.0
# msg packet_id src  36 2
# send to switch1
# msg 36 2
# id: 36, src: 2, time: 54.0, size: 100.0
# msg packet_id src  36 3
# send to switch2
# msg 36 3
# id: 36, src: 3, time: 54.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  39 1
# send to switch3
# msg 39 1
# id: 39, src: 1, time: 58.5, size: 100.0
# msg packet_id src  39 2
# send to switch1
# msg 39 2
# id: 39, src: 2, time: 58.5, size: 100.0
# msg packet_id src  39 3
# send to switch1
# msg 39 3
# id: 39, src: 3, time: 58.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  42 1
# send to switch3
# msg 42 1
# id: 42, src: 1, time: 63.0, size: 100.0
# msg packet_id src  42 2
# send to switch1
# msg 42 2
# id: 42, src: 2, time: 63.0, size: 100.0
# msg packet_id src  42 3
# send to switch1
# msg 42 3
# id: 42, src: 3, time: 63.0, size: 100.0
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  44 1
# send to switch3
# msg 44 1
# id: 44, src: 1, time: 66.0, size: 100.0
# msg packet_id src  44 2
# send to switch3
# msg 44 2
# id: 44, src: 2, time: 66.0, size: 100.0
# msg packet_id src  44 3
# send to switch1
# msg 44 3
# id: 44, src: 3, time: 66.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  47 1
# send to switch2
# msg 47 1
# id: 47, src: 1, time: 70.5, size: 100.0
# msg packet_id src  47 2
# send to switch1
# msg 47 2
# id: 47, src: 2, time: 70.5, size: 100.0
# msg packet_id src  47 3
# send to switch1
# msg 47 3
# id: 47, src: 3, time: 70.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  50 1
# send to switch2
# msg 50 1
# id: 50, src: 1, time: 75.0, size: 100.0
# msg packet_id src  50 2
# send to switch3
# msg 50 2
# id: 50, src: 2, time: 75.0, size: 100.0
# msg packet_id src  50 3
# send to switch2
# msg 50 3
# id: 50, src: 3, time: 75.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  52 1
# send to switch2
# msg 52 1
# id: 52, src: 1, time: 78.0, size: 100.0
# msg packet_id src  52 2
# send to switch1
# msg 52 2
# id: 52, src: 2, time: 78.0, size: 100.0
# msg packet_id src  52 3
# send to switch1
# msg 52 3
# id: 52, src: 3, time: 78.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  55 1
# send to switch3
# msg 55 1
# id: 55, src: 1, time: 82.5, size: 100.0
# msg packet_id src  55 2
# send to switch3
# msg 55 2
# id: 55, src: 2, time: 82.5, size: 100.0
# msg packet_id src  55 3
# send to switch2
# msg 55 3
# id: 55, src: 3, time: 82.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  58 1
# send to switch2
# msg 58 1
# id: 58, src: 1, time: 87.0, size: 100.0
# msg packet_id src  58 2
# send to switch1
# msg 58 2
# id: 58, src: 2, time: 87.0, size: 100.0
# msg packet_id src  58 3
# send to switch2
# msg 58 3
# id: 58, src: 3, time: 87.0, size: 100.0
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  60 1
# send to switch2
# msg 60 1
# id: 60, src: 1, time: 90.0, size: 100.0
# msg packet_id src  60 2
# send to switch3
# msg 60 2
# id: 60, src: 2, time: 90.0, size: 100.0
# msg packet_id src  60 3
# send to switch2
# msg 60 3
# id: 60, src: 3, time: 90.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  63 1
# send to switch3
# msg 63 1
# id: 63, src: 1, time: 94.5, size: 100.0
# msg packet_id src  63 2
# send to switch1
# msg 63 2
# id: 63, src: 2, time: 94.5, size: 100.0
# msg packet_id src  63 3
# send to switch2
# msg 63 3
# id: 63, src: 3, time: 94.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  66 1
# send to switch2
# msg 66 1
# id: 66, src: 1, time: 99.0, size: 100.0
# msg packet_id src  66 2
# send to switch3
# msg 66 2
# id: 66, src: 2, time: 99.0, size: 100.0
# msg packet_id src  66 3
# send to switch2
# msg 66 3
# id: 66, src: 3, time: 99.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  68 1
# send to switch3
# msg 68 1
# id: 68, src: 1, time: 102.0, size: 100.0
# msg packet_id src  68 2
# send to switch1
# msg 68 2
# id: 68, src: 2, time: 102.0, size: 100.0
# msg packet_id src  68 3
# send to switch2
# msg 68 3
# id: 68, src: 3, time: 102.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  71 1
# send to switch3
# msg 71 1
# id: 71, src: 1, time: 106.5, size: 100.0
# msg packet_id src  71 2
# send to switch1
# msg 71 2
# id: 71, src: 2, time: 106.5, size: 100.0
# msg packet_id src  71 3
# send to switch2
# msg 71 3
# id: 71, src: 3, time: 106.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  74 1
# send to switch2
# msg 74 1
# id: 74, src: 1, time: 111.0, size: 100.0
# msg packet_id src  74 2
# send to switch1
# msg 74 2
# id: 74, src: 2, time: 111.0, size: 100.0
# msg packet_id src  74 3
# send to switch1
# msg 74 3
# id: 74, src: 3, time: 111.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  76 1
# send to switch2
# msg 76 1
# id: 76, src: 1, time: 114.0, size: 100.0
# msg packet_id src  76 2
# send to switch1
# msg 76 2
# id: 76, src: 2, time: 114.0, size: 100.0
# msg packet_id src  76 3
# send to switch2
# msg 76 3
# id: 76, src: 3, time: 114.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  79 1
# send to switch2
# msg 79 1
# id: 79, src: 1, time: 118.5, size: 100.0
# msg packet_id src  79 2
# send to switch1
# msg 79 2
# id: 79, src: 2, time: 118.5, size: 100.0
# msg packet_id src  79 3
# send to switch1
# msg 79 3
# id: 79, src: 3, time: 118.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  82 1
# send to switch3
# msg 82 1
# id: 82, src: 1, time: 123.0, size: 100.0
# msg packet_id src  82 2
# send to switch1
# msg 82 2
# id: 82, src: 2, time: 123.0, size: 100.0
# msg packet_id src  82 3
# send to switch1
# msg 82 3
# id: 82, src: 3, time: 123.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  84 1
# send to switch3
# msg 84 1
# id: 84, src: 1, time: 126.0, size: 100.0
# msg packet_id src  84 2
# send to switch1
# msg 84 2
# id: 84, src: 2, time: 126.0, size: 100.0
# msg packet_id src  84 3
# send to switch1
# msg 84 3
# id: 84, src: 3, time: 126.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  87 1
# send to switch2
# msg 87 1
# id: 87, src: 1, time: 130.5, size: 100.0
# msg packet_id src  87 2
# send to switch1
# msg 87 2
# id: 87, src: 2, time: 130.5, size: 100.0
# msg packet_id src  87 3
# send to switch2
# msg 87 3
# id: 87, src: 3, time: 130.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  90 1
# send to switch2
# msg 90 1
# id: 90, src: 1, time: 135.0, size: 100.0
# msg packet_id src  90 2
# send to switch1
# msg 90 2
# id: 90, src: 2, time: 135.0, size: 100.0
# msg packet_id src  90 3
# send to switch2
# msg 90 3
# id: 90, src: 3, time: 135.0, size: 100.0
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  92 1
# send to switch2
# msg 92 1
# id: 92, src: 1, time: 138.0, size: 100.0
# msg packet_id src  92 2
# send to switch1
# msg 92 2
# id: 92, src: 2, time: 138.0, size: 100.0
# msg packet_id src  92 3
# send to switch2
# msg 92 3
# id: 92, src: 3, time: 138.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  95 1
# send to switch2
# msg 95 1
# id: 95, src: 1, time: 142.5, size: 100.0
# msg packet_id src  95 2
# send to switch1
# msg 95 2
# id: 95, src: 2, time: 142.5, size: 100.0
# msg packet_id src  95 3
# send to switch2
# msg 95 3
# id: 95, src: 3, time: 142.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  98 1
# send to switch3
# msg 98 1
# id: 98, src: 1, time: 147.0, size: 100.0
# msg packet_id src  98 2
# send to switch1
# msg 98 2
# id: 98, src: 2, time: 147.0, size: 100.0
# msg packet_id src  98 3
# send to switch2
# msg 98 3
# id: 98, src: 3, time: 147.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  100 1
# send to switch3
# msg 100 1
# id: 100, src: 1, time: 150.0, size: 100.0
# msg packet_id src  100 2
# send to switch1
# msg 100 2
# id: 100, src: 2, time: 150.0, size: 100.0
# msg packet_id src  100 3
# send to switch2
# msg 100 3
# id: 100, src: 3, time: 150.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  103 1
# send to switch2
# msg 103 1
# id: 103, src: 1, time: 154.5, size: 100.0
# msg packet_id src  103 2
# send to switch1
# msg 103 2
# id: 103, src: 2, time: 154.5, size: 100.0
# msg packet_id src  103 3
# send to switch2
# msg 103 3
# id: 103, src: 3, time: 154.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  106 1
# send to switch3
# msg 106 1
# id: 106, src: 1, time: 159.0, size: 100.0
# msg packet_id src  106 2
# send to switch1
# msg 106 2
# id: 106, src: 2, time: 159.0, size: 100.0
# msg packet_id src  106 3
# send to switch2
# msg 106 3
# id: 106, src: 3, time: 159.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  108 1
# send to switch2
# msg 108 1
# id: 108, src: 1, time: 162.0, size: 100.0
# msg packet_id src  108 2
# send to switch1
# msg 108 2
# id: 108, src: 2, time: 162.0, size: 100.0
# msg packet_id src  108 3
# send to switch1
# msg 108 3
# id: 108, src: 3, time: 162.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  111 1
# send to switch3
# msg 111 1
# id: 111, src: 1, time: 166.5, size: 100.0
# msg packet_id src  111 2
# send to switch1
# msg 111 2
# id: 111, src: 2, time: 166.5, size: 100.0
# msg packet_id src  111 3
# send to switch2
# msg 111 3
# id: 111, src: 3, time: 166.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  114 1
# send to switch2
# msg 114 1
# id: 114, src: 1, time: 171.0, size: 100.0
# msg packet_id src  114 2
# send to switch3
# msg 114 2
# id: 114, src: 2, time: 171.0, size: 100.0
# msg packet_id src  114 3
# send to switch2
# msg 114 3
# id: 114, src: 3, time: 171.0, size: 100.0
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  116 1
# send to switch3
# msg 116 1
# id: 116, src: 1, time: 174.0, size: 100.0
# msg packet_id src  116 2
# send to switch1
# msg 116 2
# id: 116, src: 2, time: 174.0, size: 100.0
# msg packet_id src  116 3
# send to switch1
# msg 116 3
# id: 116, src: 3, time: 174.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  119 1
# send to switch3
# msg 119 1
# id: 119, src: 1, time: 178.5, size: 100.0
# msg packet_id src  119 2
# send to switch3
# msg 119 2
# id: 119, src: 2, time: 178.5, size: 100.0
# msg packet_id src  119 3
# send to switch2
# msg 119 3
# id: 119, src: 3, time: 178.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  122 1
# send to switch2
# msg 122 1
# id: 122, src: 1, time: 183.0, size: 100.0
# msg packet_id src  122 2
# send to switch1
# msg 122 2
# id: 122, src: 2, time: 183.0, size: 100.0
# msg packet_id src  122 3
# send to switch2
# msg 122 3
# id: 122, src: 3, time: 183.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  124 1
# send to switch3
# msg 124 1
# id: 124, src: 1, time: 186.0, size: 100.0
# msg packet_id src  124 2
# send to switch1
# msg 124 2
# id: 124, src: 2, time: 186.0, size: 100.0
# msg packet_id src  124 3
# send to switch2
# msg 124 3
# id: 124, src: 3, time: 186.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  127 1
# send to switch3
# msg 127 1
# id: 127, src: 1, time: 190.5, size: 100.0
# msg packet_id src  127 2
# send to switch1
# msg 127 2
# id: 127, src: 2, time: 190.5, size: 100.0
# msg packet_id src  127 3
# send to switch2
# msg 127 3
# id: 127, src: 3, time: 190.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  130 1
# send to switch3
# msg 130 1
# id: 130, src: 1, time: 195.0, size: 100.0
# msg packet_id src  130 2
# send to switch1
# msg 130 2
# id: 130, src: 2, time: 195.0, size: 100.0
# msg packet_id src  130 3
# send to switch2
# msg 130 3
# id: 130, src: 3, time: 195.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  132 1
# send to switch2
# msg 132 1
# id: 132, src: 1, time: 198.0, size: 100.0
# msg packet_id src  132 2
# send to switch3
# msg 132 2
# id: 132, src: 2, time: 198.0, size: 100.0
# msg packet_id src  132 3
# send to switch2
# msg 132 3
# id: 132, src: 3, time: 198.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  135 1
# send to switch3
# msg 135 1
# id: 135, src: 1, time: 202.5, size: 100.0
# msg packet_id src  135 2
# send to switch1
# msg 135 2
# id: 135, src: 2, time: 202.5, size: 100.0
# msg packet_id src  135 3
# send to switch1
# msg 135 3
# id: 135, src: 3, time: 202.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  138 1
# send to switch2
# msg 138 1
# id: 138, src: 1, time: 207.0, size: 100.0
# msg packet_id src  138 2
# send to switch1
# msg 138 2
# id: 138, src: 2, time: 207.0, size: 100.0
# msg packet_id src  138 3
# send to switch2
# msg 138 3
# id: 138, src: 3, time: 207.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  140 1
# send to switch3
# msg 140 1
# id: 140, src: 1, time: 210.0, size: 100.0
# msg packet_id src  140 2
# send to switch1
# msg 140 2
# id: 140, src: 2, time: 210.0, size: 100.0
# msg packet_id src  140 3
# send to switch2
# msg 140 3
# id: 140, src: 3, time: 210.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  143 1
# send to switch3
# msg 143 1
# id: 143, src: 1, time: 214.5, size: 100.0
# msg packet_id src  143 2
# send to switch1
# msg 143 2
# id: 143, src: 2, time: 214.5, size: 100.0
# msg packet_id src  143 3
# send to switch2
# msg 143 3
# id: 143, src: 3, time: 214.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  146 1
# send to switch2
# msg 146 1
# id: 146, src: 1, time: 219.0, size: 100.0
# msg packet_id src  146 2
# send to switch1
# msg 146 2
# id: 146, src: 2, time: 219.0, size: 100.0
# msg packet_id src  146 3
# send to switch2
# msg 146 3
# id: 146, src: 3, time: 219.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  148 1
# send to switch2
# msg 148 1
# id: 148, src: 1, time: 222.0, size: 100.0
# msg packet_id src  148 2
# send to switch1
# msg 148 2
# id: 148, src: 2, time: 222.0, size: 100.0
# msg packet_id src  148 3
# send to switch1
# msg 148 3
# id: 148, src: 3, time: 222.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  151 1
# send to switch3
# msg 151 1
# id: 151, src: 1, time: 226.5, size: 100.0
# msg packet_id src  151 2
# send to switch1
# msg 151 2
# id: 151, src: 2, time: 226.5, size: 100.0
# msg packet_id src  151 3
# send to switch2
# msg 151 3
# id: 151, src: 3, time: 226.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  154 1
# send to switch2
# msg 154 1
# id: 154, src: 1, time: 231.0, size: 100.0
# msg packet_id src  154 2
# send to switch1
# msg 154 2
# id: 154, src: 2, time: 231.0, size: 100.0
# msg packet_id src  154 3
# send to switch2
# msg 154 3
# id: 154, src: 3, time: 231.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  156 1
# send to switch2
# msg 156 1
# id: 156, src: 1, time: 234.0, size: 100.0
# msg packet_id src  156 2
# send to switch1
# msg 156 2
# id: 156, src: 2, time: 234.0, size: 100.0
# msg packet_id src  156 3
# send to switch2
# msg 156 3
# id: 156, src: 3, time: 234.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  159 1
# send to switch2
# msg 159 1
# id: 159, src: 1, time: 238.5, size: 100.0
# msg packet_id src  159 2
# send to switch1
# msg 159 2
# id: 159, src: 2, time: 238.5, size: 100.0
# msg packet_id src  159 3
# send to switch2
# msg 159 3
# id: 159, src: 3, time: 238.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  162 1
# send to switch2
# msg 162 1
# id: 162, src: 1, time: 243.0, size: 100.0
# msg packet_id src  162 2
# send to switch1
# msg 162 2
# id: 162, src: 2, time: 243.0, size: 100.0
# msg packet_id src  162 3
# send to switch1
# msg 162 3
# id: 162, src: 3, time: 243.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  164 1
# send to switch3
# msg 164 1
# id: 164, src: 1, time: 246.0, size: 100.0
# msg packet_id src  164 2
# send to switch3
# msg 164 2
# id: 164, src: 2, time: 246.0, size: 100.0
# msg packet_id src  164 3
# send to switch2
# msg 164 3
# id: 164, src: 3, time: 246.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 1
# ...
# msg 1271 2
# id: 1271, src: 2, time: 1906.5, size: 100.0
# msg packet_id src  1271 3
# send to switch2
# msg 1271 3
# id: 1271, src: 3, time: 1906.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1274 1
# send to switch2
# msg 1274 1
# id: 1274, src: 1, time: 1911.0, size: 100.0
# msg packet_id src  1274 2
# send to switch1
# msg 1274 2
# id: 1274, src: 2, time: 1911.0, size: 100.0
# msg packet_id src  1274 3
# send to switch2
# msg 1274 3
# id: 1274, src: 3, time: 1911.0, size: 100.0
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  1276 1
# send to switch2
# msg 1276 1
# id: 1276, src: 1, time: 1914.0, size: 100.0
# msg packet_id src  1276 2
# send to switch1
# msg 1276 2
# id: 1276, src: 2, time: 1914.0, size: 100.0
# msg packet_id src  1276 3
# send to switch2
# msg 1276 3
# id: 1276, src: 3, time: 1914.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  1279 1
# send to switch3
# msg 1279 1
# id: 1279, src: 1, time: 1918.5, size: 100.0
# msg packet_id src  1279 2
# send to switch3
# msg 1279 2
# id: 1279, src: 2, time: 1918.5, size: 100.0
# msg packet_id src  1279 3
# send to switch2
# msg 1279 3
# id: 1279, src: 3, time: 1918.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1282 1
# send to switch3
# msg 1282 1
# id: 1282, src: 1, time: 1923.0, size: 100.0
# msg packet_id src  1282 2
# send to switch1
# msg 1282 2
# id: 1282, src: 2, time: 1923.0, size: 100.0
# msg packet_id src  1282 3
# send to switch2
# msg 1282 3
# id: 1282, src: 3, time: 1923.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1284 1
# send to switch3
# msg 1284 1
# id: 1284, src: 1, time: 1926.0, size: 100.0
# msg packet_id src  1284 2
# send to switch1
# msg 1284 2
# id: 1284, src: 2, time: 1926.0, size: 100.0
# msg packet_id src  1284 3
# send to switch2
# msg 1284 3
# id: 1284, src: 3, time: 1926.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1287 1
# send to switch3
# msg 1287 1
# id: 1287, src: 1, time: 1930.5, size: 100.0
# msg packet_id src  1287 2
# send to switch3
# msg 1287 2
# id: 1287, src: 2, time: 1930.5, size: 100.0
# msg packet_id src  1287 3
# send to switch2
# msg 1287 3
# id: 1287, src: 3, time: 1930.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  1290 1
# send to switch3
# msg 1290 1
# id: 1290, src: 1, time: 1935.0, size: 100.0
# msg packet_id src  1290 2
# send to switch1
# msg 1290 2
# id: 1290, src: 2, time: 1935.0, size: 100.0
# msg packet_id src  1290 3
# send to switch2
# msg 1290 3
# id: 1290, src: 3, time: 1935.0, size: 100.0
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1292 1
# send to switch3
# msg 1292 1
# id: 1292, src: 1, time: 1938.0, size: 100.0
# msg packet_id src  1292 2
# send to switch1
# msg 1292 2
# id: 1292, src: 2, time: 1938.0, size: 100.0
# msg packet_id src  1292 3
# send to switch2
# msg 1292 3
# id: 1292, src: 3, time: 1938.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1295 1
# send to switch2
# msg 1295 1
# id: 1295, src: 1, time: 1942.5, size: 100.0
# msg packet_id src  1295 2
# send to switch1
# msg 1295 2
# id: 1295, src: 2, time: 1942.5, size: 100.0
# msg packet_id src  1295 3
# send to switch1
# msg 1295 3
# id: 1295, src: 3, time: 1942.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1298 1
# send to switch3
# msg 1298 1
# id: 1298, src: 1, time: 1947.0, size: 100.0
# msg packet_id src  1298 2
# send to switch1
# msg 1298 2
# id: 1298, src: 2, time: 1947.0, size: 100.0
# msg packet_id src  1298 3
# send to switch2
# msg 1298 3
# id: 1298, src: 3, time: 1947.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  1300 1
# send to switch2
# msg 1300 1
# id: 1300, src: 1, time: 1950.0, size: 100.0
# msg packet_id src  1300 2
# send to switch1
# msg 1300 2
# id: 1300, src: 2, time: 1950.0, size: 100.0
# msg packet_id src  1300 3
# send to switch1
# msg 1300 3
# id: 1300, src: 3, time: 1950.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1303 1
# send to switch2
# msg 1303 1
# id: 1303, src: 1, time: 1954.5, size: 100.0
# msg packet_id src  1303 2
# send to switch1
# msg 1303 2
# id: 1303, src: 2, time: 1954.5, size: 100.0
# msg packet_id src  1303 3
# send to switch2
# msg 1303 3
# id: 1303, src: 3, time: 1954.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  1306 1
# send to switch3
# msg 1306 1
# id: 1306, src: 1, time: 1959.0, size: 100.0
# msg packet_id src  1306 2
# send to switch1
# msg 1306 2
# id: 1306, src: 2, time: 1959.0, size: 100.0
# msg packet_id src  1306 3
# send to switch1
# msg 1306 3
# id: 1306, src: 3, time: 1959.0, size: 100.0
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1308 1
# send to switch3
# msg 1308 1
# id: 1308, src: 1, time: 1962.0, size: 100.0
# msg packet_id src  1308 2
# send to switch1
# msg 1308 2
# id: 1308, src: 2, time: 1962.0, size: 100.0
# msg packet_id src  1308 3
# send to switch2
# msg 1308 3
# id: 1308, src: 3, time: 1962.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  1311 1
# send to switch3
# msg 1311 1
# id: 1311, src: 1, time: 1966.5, size: 100.0
# msg packet_id src  1311 2
# send to switch1
# msg 1311 2
# id: 1311, src: 2, time: 1966.5, size: 100.0
# msg packet_id src  1311 3
# send to switch2
# msg 1311 3
# id: 1311, src: 3, time: 1966.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1314 1
# send to switch3
# msg 1314 1
# id: 1314, src: 1, time: 1971.0, size: 100.0
# msg packet_id src  1314 2
# send to switch3
# msg 1314 2
# id: 1314, src: 2, time: 1971.0, size: 100.0
# msg packet_id src  1314 3
# send to switch2
# msg 1314 3
# id: 1314, src: 3, time: 1971.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  1316 1
# send to switch2
# msg 1316 1
# id: 1316, src: 1, time: 1974.0, size: 100.0
# msg packet_id src  1316 2
# send to switch1
# msg 1316 2
# id: 1316, src: 2, time: 1974.0, size: 100.0
# msg packet_id src  1316 3
# send to switch1
# msg 1316 3
# id: 1316, src: 3, time: 1974.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 3
# opt_path [1, 2, 3]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 1
# opt_path [2, 3, 1]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1319 1
# send to switch3
# msg 1319 1
# id: 1319, src: 1, time: 1978.5, size: 100.0
# msg packet_id src  1319 2
# send to switch1
# msg 1319 2
# id: 1319, src: 2, time: 1978.5, size: 100.0
# msg packet_id src  1319 3
# send to switch2
# msg 1319 3
# id: 1319, src: 3, time: 1978.5, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# msg packet_id src  1322 1
# send to switch2
# msg 1322 1
# id: 1322, src: 1, time: 1983.0, size: 100.0
# msg packet_id src  1322 2
# send to switch1
# msg 1322 2
# id: 1322, src: 2, time: 1983.0, size: 100.0
# msg packet_id src  1322 3
# send to switch1
# msg 1322 3
# id: 1322, src: 3, time: 1983.0, size: 100.0
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# destination 2
# opt_path [1, 3, 2]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# msg packet_id src  1324 1
# send to switch3
# msg 1324 1
# id: 1324, src: 1, time: 1986.0, size: 100.0
# msg packet_id src  1324 2
# send to switch1
# msg 1324 2
# id: 1324, src: 2, time: 1986.0, size: 100.0
# msg packet_id src  1324 3
# send to switch2
# msg 1324 3
# id: 1324, src: 3, time: 1986.0, size: 100.0
# self.store <simpy.resources.store.Store object at 0x0000023637E19408>
# self.store <simpy.resources.store.Store object at 0x0000023637F751C8>
# self.store <simpy.resources.store.Store object at 0x0000023637F75F88>
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 2
# opt_path [3, 1, 2]
# destination 3
# opt_path [1, 2, 3]
# destination 3
# opt_path [2, 1, 3]
# destination 1
# opt_path [3, 2, 1]
# sink 1 waits: []
# 1 received: 0, dropped 1381, sent 1333
# sink 2 waits: []
# 2 received: 0, dropped 1416, sent 1333
# sink 3 waits: []
# 3 received: 0, dropped 1193, sent 1333

# %%
env = simpy.Environment()  # Create the SimPy environment
ps = PacketSink(env, debug=True) # debug: every packet arrival is printed
pg = PacketGenerator(env, "SJSU", constArrival, constSize)
switch_port = SwitchPort(env, rate=200.0, qlimit=300)
switch_port2 = SwitchPort(env, rate=200.0, qlimit=300)
switch_port3 = SwitchPort(env, rate=200.0, qlimit=300)
# Wire packet generators and sinks together
pg.out = switch_port
switch_port.out = switch_port2
switch_port2.out = switch_port3
switch_port3.out = ps
env.run(until=20)
print("waits: {}".format(ps.waits))
print("received: {}, dropped {}, sent {}".format(ps.packets_rec,
     switch_port.packets_drop, pg.packets_sent))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-e8a24d39b064> in <module>
#       1 env = simpy.Environment()  # Create the SimPy environment
#       2 ps = PacketSink(env, debug=True) # debug: every packet arrival is printed
# ----> 3 pg = PacketGenerator(env, "SJSU", constArrival, constSize)
#       4 switch_port = SwitchPort(env, rate=200.0, qlimit=300)
#       5 switch_port2 = SwitchPort(env, rate=200.0, qlimit=300)
#
# TypeError: __init__() missing 1 required positional argument: 'sdist'

# %%
from numpy.random import choice

# %%
prob=[0.5,0.5,0]

# %%
draw = choice([3,4,5], 
              p=prob)

# %%
draw
